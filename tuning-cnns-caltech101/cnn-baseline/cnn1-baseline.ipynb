# %%
import yaml
import argparse
import os
import sys
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Go up 1 directory level to import the helpers foldes
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# From local helper files
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helpers.helper_dataset import get_dataloaders_caltech101

# %%
##########################
### SETTINGS
##########################
parser = argparse.ArgumentParser()
script_dir = os.path.dirname(os.path.abspath('cnn1-baseline.ipynb'))
default_yaml = os.path.join(script_dir, 'config-baseline.yaml')
parser.add_argument('--settings_path',
                    type=str,
                    default=default_yaml,
                    help='Path to the YAML config file')

args, unknown = parser.parse_known_args() # Ignore unknown arguments

# Load YAML settings
with open(args.settings_path, 'r') as file:
    SETTINGS = yaml.load(file, Loader=yaml.FullLoader)

if torch.cuda.is_available():
    DEVICE = torch.device(f"cuda:{SETTINGS.get('cuda_device', 0)}")
else:
    DEVICE = torch.device('cpu')

# Set random seeds, etc.
set_all_seeds(SETTINGS['random_seed'])
# set_deterministic

# %%
##########################
### DATASET & DATALOADERS
##########################
resize_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((32, 32)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_loader, valid_loader, test_loader = get_dataloaders_caltech101(
    batch_size=SETTINGS['batch_size'],
    validation_fraction=SETTINGS['validation_percent'],
    train_transforms=resize_transform,
    test_transforms=resize_transform
)

##########################
### MODEL DEFINITION
##########################

class myCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # (1) 1st Convolutional Layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=11, stride=4, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (2) 2nd Convolutional Layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=5, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (4) Fully Connected Layers + Activation
        self.fc1 = nn.Sequential(
            nn.Linear(192 * 1 * 1, 512),
            nn.Tanh(),
            nn.Linear(512, num_classes)
        )

    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x


model = myCNN(num_classes=SETTINGS['num_classes'])
model.to(SETTINGS['cuda_device'])


##########################
### WEIGHT INITIALIZATION
##########################
def apply_weight_init(model, init_name='none'):
    """
    Apply weight initialization to Conv2d and Linear layers
    within an nn.Sequential model.
    """
    for layer in model.modules():
        if isinstance(layer, (nn.Conv2d, nn.Linear)):
            if init_name == 'xavier_uniform':
                nn.init.xavier_uniform_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'kaiming_normal':
                nn.init.kaiming_normal_(layer.weight, nonlinearity='relu')
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'orthogonal':
                nn.init.orthogonal_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            else:
                # If none or unknown, just leave PyTorch default
                pass

# Read weight init scheme from config
weight_init_config = SETTINGS.get('weight_init', {})
weight_init_name = weight_init_config.get('name', 'none')

apply_weight_init(model, init_name=weight_init_name)

##########################
### OPTIMIZER
##########################
optimizer_config = SETTINGS.get('optimizer', {})
optimizer_name = optimizer_config.get('name', 'Adam') # Default to Adam

weight_decay = float(optimizer_config.get('weight_decay', 0.0))
momentum = float(optimizer_config.get('momentum', 0.0)) # Default momentum for SGD
alpha = float(optimizer_config.get('alpha', 0.99)) # Default alpha for RMSprop

if optimizer_name == 'Adam':
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        weight_decay=weight_decay
    )
    
elif optimizer_name == 'SGD':
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay
    )

elif optimizer_name == 'RMSprop':
    optimizer = torch.optim.RMSProp(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay,
        alpha=alpha
    )

else:
    raise ValueError(f"Unknown optimizer: {optimizer_name}")

##########################
### LR SCHEDULER
##########################
scheduler_config = SETTINGS.get('scheduler', {})
scheduler_name = scheduler_config.get('name', 'None')

# Default to ReduceLROnPlateau, if not specified
if scheduler_name == 'ReduceLROnPlateau':
    factor = scheduler_config.get('factor', 0.1)
    mode = scheduler_config.get('mode', 'max')
    patience = scheduler_config.get('patience', 5)
    verbose = scheduler_config.get('verbose', True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        factor=factor,
        mode=mode,
        patience=patience
    )
elif scheduler_name == 'ExponentialLR':
    gamma = scheduler_config.get('gamma', 0.99)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name == 'StepLR':
    step_size = scheduler_config.get('step_size', 30)
    gamma = scheduler_config.get('gamma', 0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name.lower() == 'none':
    scheduler = None
else:
    raise ValueError(f"Unknown scheduler: {scheduler_name}")
# Out:
# Files already downloaded and verified

# %%
##########################
### TRAINING LOOP
##########################
# The helper_train.py presumably expects scheduler if not None,
# and you might specify how it’s applied (e.g., 'valid_acc').
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=SETTINGS['num_epochs'],
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=SETTINGS['cuda_device'],
    logging_interval=100,
    scheduler=scheduler,
    scheduler_on='valid_acc'  # or 'train_acc' or 'valid_loss'
)

##########################
### PLOTTING
##########################
plot_training_loss(
    minibatch_loss_list=minibatch_loss_list,
    num_epochs=SETTINGS['num_epochs'],
    iter_per_epoch=len(train_loader),
    results_dir=None,
    averaging_iterations=100
)
plt.show()

plot_accuracy(
    train_acc_list=train_acc_list,
    valid_acc_list=valid_acc_list,
    results_dir=None
)
plt.ylim([0, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0032 | Loss: 4.6167
# Epoch: 001/100 | Train: 9.11% | Validation: 11.55%
# Time elapsed: 0.27 min
# Epoch: 002/100 | Batch 0000/0032 | Loss: 4.3989
# Epoch: 002/100 | Train: 10.89% | Validation: 15.24%
# Time elapsed: 0.53 min
# Epoch: 003/100 | Batch 0000/0032 | Loss: 4.1479
# Epoch: 003/100 | Train: 17.92% | Validation: 21.48%
# Time elapsed: 0.77 min
# Epoch: 004/100 | Batch 0000/0032 | Loss: 4.0083
# Epoch: 004/100 | Train: 22.20% | Validation: 26.56%
# Time elapsed: 1.02 min
# Epoch: 005/100 | Batch 0000/0032 | Loss: 3.8957
# Epoch: 005/100 | Train: 24.02% | Validation: 28.87%
# Time elapsed: 1.28 min
# Epoch: 006/100 | Batch 0000/0032 | Loss: 3.7019
# Epoch: 006/100 | Train: 26.73% | Validation: 31.18%
# Time elapsed: 1.54 min
# Epoch: 007/100 | Batch 0000/0032 | Loss: 3.3895
# Epoch: 007/100 | Train: 29.19% | Validation: 33.26%
# Time elapsed: 1.79 min
# Epoch: 008/100 | Batch 0000/0032 | Loss: 3.3256
# Epoch: 008/100 | Train: 30.08% | Validation: 33.72%
# Time elapsed: 2.04 min
# Epoch: 009/100 | Batch 0000/0032 | Loss: 3.2459
# Epoch: 009/100 | Train: 32.35% | Validation: 34.87%
# Time elapsed: 2.29 min
# Epoch: 010/100 | Batch 0000/0032 | Loss: 3.2703
# Epoch: 010/100 | Train: 34.22% | Validation: 37.41%
# Time elapsed: 2.54 min
# Epoch: 011/100 | Batch 0000/0032 | Loss: 3.0662
# Epoch: 011/100 | Train: 35.41% | Validation: 38.80%
# Time elapsed: 2.80 min
# Epoch: 012/100 | Batch 0000/0032 | Loss: 2.7731
# Epoch: 012/100 | Train: 37.01% | Validation: 39.95%
# Time elapsed: 3.05 min
# Epoch: 013/100 | Batch 0000/0032 | Loss: 2.8714
# Epoch: 013/100 | Train: 39.12% | Validation: 42.96%
# Time elapsed: 3.30 min
# Epoch: 014/100 | Batch 0000/0032 | Loss: 2.6486
# Epoch: 014/100 | Train: 40.98% | Validation: 44.80%
# Time elapsed: 3.55 min
# Epoch: 015/100 | Batch 0000/0032 | Loss: 2.6039
# Epoch: 015/100 | Train: 42.13% | Validation: 45.73%
# Time elapsed: 3.81 min
# Epoch: 016/100 | Batch 0000/0032 | Loss: 2.7074
# Epoch: 016/100 | Train: 43.76% | Validation: 45.96%
# Time elapsed: 4.06 min
# Epoch: 017/100 | Batch 0000/0032 | Loss: 2.8086
# Epoch: 017/100 | Train: 44.92% | Validation: 48.50%
# Time elapsed: 4.31 min
# Epoch: 018/100 | Batch 0000/0032 | Loss: 2.4324
# Epoch: 018/100 | Train: 46.79% | Validation: 48.04%
# Time elapsed: 4.56 min
# Epoch: 019/100 | Batch 0000/0032 | Loss: 2.4099
# Epoch: 019/100 | Train: 48.18% | Validation: 50.12%
# Time elapsed: 4.81 min
# Epoch: 020/100 | Batch 0000/0032 | Loss: 2.4235
# Epoch: 020/100 | Train: 49.56% | Validation: 49.88%
# Time elapsed: 5.06 min
# Epoch: 021/100 | Batch 0000/0032 | Loss: 2.2592
# Epoch: 021/100 | Train: 50.84% | Validation: 51.50%
# Time elapsed: 5.31 min
# Epoch: 022/100 | Batch 0000/0032 | Loss: 2.1416
# Epoch: 022/100 | Train: 51.88% | Validation: 51.04%
# Time elapsed: 5.56 min
# Epoch: 023/100 | Batch 0000/0032 | Loss: 1.9583
# Epoch: 023/100 | Train: 53.32% | Validation: 52.19%
# Time elapsed: 5.81 min
# Epoch: 024/100 | Batch 0000/0032 | Loss: 2.0652
# Epoch: 024/100 | Train: 54.50% | Validation: 53.35%
# Time elapsed: 6.06 min
# Epoch: 025/100 | Batch 0000/0032 | Loss: 1.9286
# Epoch: 025/100 | Train: 55.82% | Validation: 53.81%
# Time elapsed: 6.31 min
# Epoch: 026/100 | Batch 0000/0032 | Loss: 2.0531
# Epoch: 026/100 | Train: 56.32% | Validation: 53.81%
# Time elapsed: 6.56 min
# Epoch: 027/100 | Batch 0000/0032 | Loss: 1.7320
# Epoch: 027/100 | Train: 57.58% | Validation: 54.73%
# Time elapsed: 6.81 min
# Epoch: 028/100 | Batch 0000/0032 | Loss: 1.9517
# Epoch: 028/100 | Train: 58.97% | Validation: 54.73%
# Time elapsed: 7.06 min
# Epoch: 029/100 | Batch 0000/0032 | Loss: 1.8972
# Epoch: 029/100 | Train: 60.38% | Validation: 55.43%
# Time elapsed: 7.32 min
# Epoch: 030/100 | Batch 0000/0032 | Loss: 1.7521
# Epoch: 030/100 | Train: 61.32% | Validation: 55.43%
# Time elapsed: 7.57 min
# Epoch: 031/100 | Batch 0000/0032 | Loss: 1.6088
# Epoch: 031/100 | Train: 62.40% | Validation: 56.12%
# Time elapsed: 7.82 min
# Epoch: 032/100 | Batch 0000/0032 | Loss: 1.5548
# Epoch: 032/100 | Train: 63.28% | Validation: 55.20%
# Time elapsed: 8.07 min
# Epoch: 033/100 | Batch 0000/0032 | Loss: 1.4922
# Epoch: 033/100 | Train: 64.45% | Validation: 55.89%
# Time elapsed: 8.32 min
# Epoch: 034/100 | Batch 0000/0032 | Loss: 1.5606
# Epoch: 034/100 | Train: 65.43% | Validation: 56.12%
# Time elapsed: 8.58 min
# Epoch: 035/100 | Batch 0000/0032 | Loss: 1.7807
# Epoch: 035/100 | Train: 66.19% | Validation: 55.66%
# Time elapsed: 8.83 min
# Epoch: 036/100 | Batch 0000/0032 | Loss: 1.3434
# Epoch: 036/100 | Train: 67.31% | Validation: 55.89%
# Time elapsed: 9.08 min
# Epoch: 037/100 | Batch 0000/0032 | Loss: 1.3231
# Epoch: 037/100 | Train: 68.43% | Validation: 55.89%
# Time elapsed: 9.33 min
# Epoch: 038/100 | Batch 0000/0032 | Loss: 1.4447
# Epoch: 038/100 | Train: 68.88% | Validation: 56.35%
# Time elapsed: 9.57 min
# Epoch: 039/100 | Batch 0000/0032 | Loss: 1.4630
# Epoch: 039/100 | Train: 68.69% | Validation: 56.58%
# Time elapsed: 9.82 min
# Epoch: 040/100 | Batch 0000/0032 | Loss: 1.3738
# Epoch: 040/100 | Train: 68.76% | Validation: 56.58%
# Time elapsed: 10.07 min
# Epoch: 041/100 | Batch 0000/0032 | Loss: 1.4727
# Epoch: 041/100 | Train: 69.06% | Validation: 57.27%
# Time elapsed: 10.32 min
# Epoch: 042/100 | Batch 0000/0032 | Loss: 1.2363
# Epoch: 042/100 | Train: 69.09% | Validation: 57.04%
# Time elapsed: 10.58 min
# Epoch: 043/100 | Batch 0000/0032 | Loss: 1.3074
# Epoch: 043/100 | Train: 69.10% | Validation: 56.58%
# Time elapsed: 10.83 min
# Epoch: 044/100 | Batch 0000/0032 | Loss: 1.3711
# Epoch: 044/100 | Train: 69.23% | Validation: 56.58%
# Time elapsed: 11.07 min
# Epoch: 045/100 | Batch 0000/0032 | Loss: 1.3780
# Epoch: 045/100 | Train: 69.45% | Validation: 56.58%
# Time elapsed: 11.32 min
# Epoch: 046/100 | Batch 0000/0032 | Loss: 1.2958
# Epoch: 046/100 | Train: 69.49% | Validation: 56.81%
# Time elapsed: 11.57 min
# Epoch: 047/100 | Batch 0000/0032 | Loss: 1.1793
# Epoch: 047/100 | Train: 69.63% | Validation: 56.81%
# Time elapsed: 11.82 min
# Epoch: 048/100 | Batch 0000/0032 | Loss: 1.2442
# Epoch: 048/100 | Train: 69.60% | Validation: 56.81%
# Time elapsed: 12.07 min
# Epoch: 049/100 | Batch 0000/0032 | Loss: 1.3192
# Epoch: 049/100 | Train: 69.74% | Validation: 57.04%
# Time elapsed: 12.32 min
# Epoch: 050/100 | Batch 0000/0032 | Loss: 1.3066
# Epoch: 050/100 | Train: 69.68% | Validation: 57.04%
# Time elapsed: 12.57 min
# Epoch: 051/100 | Batch 0000/0032 | Loss: 1.4107
# Epoch: 051/100 | Train: 69.70% | Validation: 57.27%
# Time elapsed: 12.82 min
# Epoch: 052/100 | Batch 0000/0032 | Loss: 1.3083
# Epoch: 052/100 | Train: 69.67% | Validation: 57.04%
# Time elapsed: 13.07 min
# Epoch: 053/100 | Batch 0000/0032 | Loss: 1.2438
# Epoch: 053/100 | Train: 69.69% | Validation: 57.04%
# Time elapsed: 13.32 min
# Epoch: 054/100 | Batch 0000/0032 | Loss: 1.2290
# Epoch: 054/100 | Train: 69.68% | Validation: 57.04%
# Time elapsed: 13.57 min
# Epoch: 055/100 | Batch 0000/0032 | Loss: 1.3596
# Epoch: 055/100 | Train: 69.76% | Validation: 57.04%
# Time elapsed: 13.82 min
# Epoch: 056/100 | Batch 0000/0032 | Loss: 1.3999
# Epoch: 056/100 | Train: 69.63% | Validation: 57.04%
# Time elapsed: 14.08 min
# Epoch: 057/100 | Batch 0000/0032 | Loss: 1.1718
# Epoch: 057/100 | Train: 69.69% | Validation: 57.04%
# Time elapsed: 14.32 min
# Epoch: 058/100 | Batch 0000/0032 | Loss: 1.1572
# Epoch: 058/100 | Train: 69.70% | Validation: 57.04%
# Time elapsed: 14.57 min
# Epoch: 059/100 | Batch 0000/0032 | Loss: 1.2760
# Epoch: 059/100 | Train: 69.74% | Validation: 57.04%
# Time elapsed: 14.82 min
# Epoch: 060/100 | Batch 0000/0032 | Loss: 1.3976
# Epoch: 060/100 | Train: 69.74% | Validation: 57.04%
# Time elapsed: 15.07 min
# Epoch: 061/100 | Batch 0000/0032 | Loss: 1.3097
# Epoch: 061/100 | Train: 69.70% | Validation: 57.04%
# Time elapsed: 15.32 min
# Epoch: 062/100 | Batch 0000/0032 | Loss: 1.2526
# Epoch: 062/100 | Train: 69.74% | Validation: 57.04%
# Time elapsed: 15.57 min
# Epoch: 063/100 | Batch 0000/0032 | Loss: 1.3126
# Epoch: 063/100 | Train: 69.70% | Validation: 57.04%
# Time elapsed: 15.82 min
# Epoch: 064/100 | Batch 0000/0032 | Loss: 1.2683
# Epoch: 064/100 | Train: 69.70% | Validation: 57.04%
# Time elapsed: 16.07 min
# Epoch: 065/100 | Batch 0000/0032 | Loss: 1.4057
# Epoch: 065/100 | Train: 69.69% | Validation: 57.04%
# Time elapsed: 16.32 min
# Epoch: 066/100 | Batch 0000/0032 | Loss: 1.2640
# Epoch: 066/100 | Train: 69.64% | Validation: 57.04%
# Time elapsed: 16.57 min
# Epoch: 067/100 | Batch 0000/0032 | Loss: 1.3909
# Epoch: 067/100 | Train: 69.71% | Validation: 57.04%
# Time elapsed: 16.81 min
# Epoch: 068/100 | Batch 0000/0032 | Loss: 1.2900
# Epoch: 068/100 | Train: 69.71% | Validation: 57.04%
# Time elapsed: 17.06 min
# Epoch: 069/100 | Batch 0000/0032 | Loss: 1.1865
# Epoch: 069/100 | Train: 69.70% | Validation: 57.04%
# Time elapsed: 17.31 min
# Epoch: 070/100 | Batch 0000/0032 | Loss: 1.2810
# Epoch: 070/100 | Train: 69.71% | Validation: 57.04%
# Time elapsed: 17.57 min
# Epoch: 071/100 | Batch 0000/0032 | Loss: 1.3627
# Epoch: 071/100 | Train: 69.69% | Validation: 57.04%
# Time elapsed: 17.82 min
# Epoch: 072/100 | Batch 0000/0032 | Loss: 1.4513
# Epoch: 072/100 | Train: 69.67% | Validation: 57.04%
# Time elapsed: 18.07 min
# Epoch: 073/100 | Batch 0000/0032 | Loss: 1.3947
# Epoch: 073/100 | Train: 69.69% | Validation: 57.04%
# Time elapsed: 18.32 min
# Epoch: 074/100 | Batch 0000/0032 | Loss: 1.2525
# Epoch: 074/100 | Train: 69.64% | Validation: 57.04%
# Time elapsed: 18.57 min
# Epoch: 075/100 | Batch 0000/0032 | Loss: 1.2571
# Epoch: 075/100 | Train: 69.70% | Validation: 57.04%
# Time elapsed: 18.82 min
# Epoch: 076/100 | Batch 0000/0032 | Loss: 1.2751
# Epoch: 076/100 | Train: 69.76% | Validation: 57.04%
# Time elapsed: 19.07 min
# Epoch: 077/100 | Batch 0000/0032 | Loss: 1.2435
# Epoch: 077/100 | Train: 69.80% | Validation: 57.04%
# Time elapsed: 19.32 min
# Epoch: 078/100 | Batch 0000/0032 | Loss: 1.2816
# Epoch: 078/100 | Train: 69.70% | Validation: 57.04%
# Time elapsed: 19.57 min
# Epoch: 079/100 | Batch 0000/0032 | Loss: 1.3237
# Epoch: 079/100 | Train: 69.67% | Validation: 57.04%
# Time elapsed: 19.81 min
# Epoch: 080/100 | Batch 0000/0032 | Loss: 1.2581
# Epoch: 080/100 | Train: 69.71% | Validation: 57.04%
# Time elapsed: 20.06 min
# Epoch: 081/100 | Batch 0000/0032 | Loss: 1.4592
# Epoch: 081/100 | Train: 69.74% | Validation: 57.04%
# Time elapsed: 20.31 min
# Epoch: 082/100 | Batch 0000/0032 | Loss: 1.2959
# Epoch: 082/100 | Train: 69.68% | Validation: 57.04%
# Time elapsed: 20.56 min
# Epoch: 083/100 | Batch 0000/0032 | Loss: 1.2717
# Epoch: 083/100 | Train: 69.76% | Validation: 57.04%
# Time elapsed: 20.81 min
# Epoch: 084/100 | Batch 0000/0032 | Loss: 1.3938
# Epoch: 084/100 | Train: 69.71% | Validation: 57.04%
# Time elapsed: 21.06 min
# Epoch: 085/100 | Batch 0000/0032 | Loss: 1.4545
# Epoch: 085/100 | Train: 69.76% | Validation: 57.04%
# Time elapsed: 21.31 min
# Epoch: 086/100 | Batch 0000/0032 | Loss: 1.2029
# Epoch: 086/100 | Train: 69.64% | Validation: 57.04%
# Time elapsed: 21.56 min
# Epoch: 087/100 | Batch 0000/0032 | Loss: 1.4154
# Epoch: 087/100 | Train: 69.70% | Validation: 57.04%
# Time elapsed: 21.81 min
# Epoch: 088/100 | Batch 0000/0032 | Loss: 1.2957
# Epoch: 088/100 | Train: 69.71% | Validation: 57.04%
# Time elapsed: 22.06 min
# Epoch: 089/100 | Batch 0000/0032 | Loss: 1.2449
# Epoch: 089/100 | Train: 69.75% | Validation: 57.04%
# Time elapsed: 22.30 min
# Epoch: 090/100 | Batch 0000/0032 | Loss: 1.3474
# Epoch: 090/100 | Train: 69.74% | Validation: 57.04%
# Time elapsed: 22.55 min
# Epoch: 091/100 | Batch 0000/0032 | Loss: 1.2234
# Epoch: 091/100 | Train: 69.75% | Validation: 57.04%
# Time elapsed: 22.79 min
# Epoch: 092/100 | Batch 0000/0032 | Loss: 1.3333
# Epoch: 092/100 | Train: 69.76% | Validation: 57.04%
# Time elapsed: 23.03 min
# Epoch: 093/100 | Batch 0000/0032 | Loss: 1.3062
# Epoch: 093/100 | Train: 69.65% | Validation: 57.04%
# Time elapsed: 23.27 min
# Epoch: 094/100 | Batch 0000/0032 | Loss: 1.2945
# Epoch: 094/100 | Train: 69.67% | Validation: 57.04%
# Time elapsed: 23.51 min
# Epoch: 095/100 | Batch 0000/0032 | Loss: 1.2439
# Epoch: 095/100 | Train: 69.69% | Validation: 57.04%
# Time elapsed: 23.75 min
# Epoch: 096/100 | Batch 0000/0032 | Loss: 1.4676
# Epoch: 096/100 | Train: 69.74% | Validation: 57.04%
# Time elapsed: 23.99 min
# Epoch: 097/100 | Batch 0000/0032 | Loss: 1.2207
# Epoch: 097/100 | Train: 69.76% | Validation: 57.04%
# Time elapsed: 24.24 min
# Epoch: 098/100 | Batch 0000/0032 | Loss: 1.3314
# Epoch: 098/100 | Train: 69.64% | Validation: 57.04%
# Time elapsed: 24.48 min
# Epoch: 099/100 | Batch 0000/0032 | Loss: 1.4203
# Epoch: 099/100 | Train: 69.70% | Validation: 57.04%
# Time elapsed: 24.72 min
# Epoch: 100/100 | Batch 0000/0032 | Loss: 1.2621
# Epoch: 100/100 | Train: 69.62% | Validation: 57.04%
# Time elapsed: 24.96 min
# Total Training Time: 24.96 min
# Test accuracy 69.08%

# %%
from torchsummary import summary
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1             [-1, 64, 7, 7]          23,296
#               Tanh-2             [-1, 64, 7, 7]               0
#          MaxPool2d-3             [-1, 64, 3, 3]               0
#             Conv2d-4            [-1, 192, 3, 3]         307,392
#               Tanh-5            [-1, 192, 3, 3]               0
#          MaxPool2d-6            [-1, 192, 1, 1]               0
#             Linear-7                  [-1, 512]          98,816
#               Tanh-8                  [-1, 512]               0
#             Linear-9                  [-1, 101]          51,813
# ================================================================
# Total params: 481,317
# Trainable params: 481,317
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.09
# Params size (MB): 1.84
# Estimated Total Size (MB): 1.94
# ----------------------------------------------------------------

# %%
##########################
### SAVE MODEL
##########################
model.to(torch.device('cpu'))
os.makedirs('./models/cnn1-baseline', exist_ok=True)
torch.save(model.state_dict(), './models/cnn1-baseline/cnn1-baseline.pt')
torch.save(optimizer.state_dict(), './models/cnn1-baseline/cnn1-baseline-optimizer.pt')
torch.save(scheduler.state_dict(), './models/cnn1-baseline/cnn1-baseline-scheduler.pt')
