# %%
import yaml
import argparse
import os
import sys
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Go up 1 directory level to import the helpers foldes
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# From local helper files
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helpers.helper_dataset import get_dataloaders_caltech101

# %%
##########################
### SETTINGS
##########################
parser = argparse.ArgumentParser()
script_dir = os.path.dirname(os.path.abspath('cnn1-baseline.ipynb'))
default_yaml = os.path.join(script_dir, 'config-baseline.yaml')
parser.add_argument('--settings_path',
                    type=str,
                    default=default_yaml,
                    help='Path to the YAML config file')

args, unknown = parser.parse_known_args() # Ignore unknown arguments

# Load YAML settings
with open(args.settings_path, 'r') as file:
    SETTINGS = yaml.load(file, Loader=yaml.FullLoader)

if torch.cuda.is_available():
    DEVICE = torch.device(f"cuda:{SETTINGS.get('cuda_device', 0)}")
else:
    DEVICE = torch.device('cpu')

# Set random seeds, etc.
set_all_seeds(SETTINGS['random_seed'])
# set_deterministic

# %%
##########################
### DATASET & DATALOADERS
##########################
resize_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((32, 32)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_loader, valid_loader, test_loader = get_dataloaders_caltech101(
    batch_size=SETTINGS['batch_size'],
    validation_fraction=SETTINGS['validation_percent'],
    train_transforms=resize_transform,
    test_transforms=resize_transform
)

##########################
### MODEL DEFINITION
##########################

class myCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # (1) 1st Convolutional Layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=11, stride=4, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (2) 2nd Convolutional Layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (3) 3rd Convolutional Layer
        self.conv3 = nn.Sequential(
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=1, stride=1)
        )

        # (4) 2 Fully Connected Layers + Activation
        self.fc1 = nn.Sequential(
            nn.Linear(384 * 1 * 1, 512),
            nn.Tanh(),
            nn.Linear(512, num_classes)
        )

    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = x.view(x.size(0),-1)
        x = self.fc1(x)
        return x


model = myCNN(num_classes=SETTINGS['num_classes'])

model.to(SETTINGS['cuda_device'])


##########################
### WEIGHT INITIALIZATION
##########################
def apply_weight_init(model, init_name='none'):
    """
    Apply weight initialization to Conv2d and Linear layers
    within an nn.Sequential model.
    """
    for layer in model.modules():
        if isinstance(layer, (nn.Conv2d, nn.Linear)):
            if init_name == 'xavier_uniform':
                nn.init.xavier_uniform_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'kaiming_normal':
                nn.init.kaiming_normal_(layer.weight, nonlinearity='relu')
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'orthogonal':
                nn.init.orthogonal_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            else:
                # If none or unknown, just leave PyTorch default
                pass

# Read weight init scheme from config
weight_init_config = SETTINGS.get('weight_init', {})
weight_init_name = weight_init_config.get('name', 'none')

apply_weight_init(model, init_name=weight_init_name)

##########################
### OPTIMIZER
##########################
optimizer_config = SETTINGS.get('optimizer', {})
optimizer_name = optimizer_config.get('name', 'Adam') # Default to Adam

weight_decay = float(optimizer_config.get('weight_decay', 0.0))
momentum = float(optimizer_config.get('momentum', 0.0)) # Default momentum for SGD
alpha = float(optimizer_config.get('alpha', 0.99)) # Default alpha for RMSprop

if optimizer_name == 'Adam':
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        weight_decay=weight_decay
    )
    
elif optimizer_name == 'SGD':
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay
    )

elif optimizer_name == 'RMSprop':
    optimizer = torch.optim.RMSProp(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay,
        alpha=alpha
    )

else:
    raise ValueError(f"Unknown optimizer: {optimizer_name}")

##########################
### LR SCHEDULER
##########################
scheduler_config = SETTINGS.get('scheduler', {})
scheduler_name = scheduler_config.get('name', 'None')

# Default to ReduceLROnPlateau, if not specified
if scheduler_name == 'ReduceLROnPlateau':
    factor = scheduler_config.get('factor', 0.1)
    mode = scheduler_config.get('mode', 'max')
    patience = scheduler_config.get('patience', 5)
    verbose = scheduler_config.get('verbose', True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        factor=factor,
        mode=mode,
        patience=patience
    )
elif scheduler_name == 'ExponentialLR':
    gamma = scheduler_config.get('gamma', 0.99)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name == 'StepLR':
    step_size = scheduler_config.get('step_size', 30)
    gamma = scheduler_config.get('gamma', 0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name.lower() == 'none':
    scheduler = None
else:
    raise ValueError(f"Unknown scheduler: {scheduler_name}")
# Out:
# Files already downloaded and verified

# %%
##########################
### TRAINING LOOP
##########################
# The helper_train.py presumably expects scheduler if not None,
# and you might specify how it’s applied (e.g., 'valid_acc').
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=SETTINGS['num_epochs'],
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=SETTINGS['cuda_device'],
    logging_interval=100,
    scheduler=scheduler,
    scheduler_on='valid_acc'  # or 'train_acc' or 'valid_loss'
)

##########################
### PLOTTING
##########################
plot_training_loss(
    minibatch_loss_list=minibatch_loss_list,
    num_epochs=SETTINGS['num_epochs'],
    iter_per_epoch=len(train_loader),
    results_dir=None,
    averaging_iterations=100
)
plt.show()

plot_accuracy(
    train_acc_list=train_acc_list,
    valid_acc_list=valid_acc_list,
    results_dir=None
)
plt.ylim([0, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0032 | Loss: 4.6217
# Epoch: 001/100 | Train: 10.96% | Validation: 15.47%
# Time elapsed: 0.27 min
# Epoch: 002/100 | Batch 0000/0032 | Loss: 4.5076
# Epoch: 002/100 | Train: 9.07% | Validation: 11.55%
# Time elapsed: 0.53 min
# Epoch: 003/100 | Batch 0000/0032 | Loss: 4.2837
# Epoch: 003/100 | Train: 9.09% | Validation: 11.32%
# Time elapsed: 0.79 min
# Epoch: 004/100 | Batch 0000/0032 | Loss: 4.2817
# Epoch: 004/100 | Train: 5.87% | Validation: 4.85%
# Time elapsed: 1.04 min
# Epoch: 005/100 | Batch 0000/0032 | Loss: 4.2401
# Epoch: 005/100 | Train: 9.23% | Validation: 11.55%
# Time elapsed: 1.29 min
# Epoch: 006/100 | Batch 0000/0032 | Loss: 4.0290
# Epoch: 006/100 | Train: 16.59% | Validation: 19.17%
# Time elapsed: 1.55 min
# Epoch: 007/100 | Batch 0000/0032 | Loss: 3.9259
# Epoch: 007/100 | Train: 19.48% | Validation: 24.48%
# Time elapsed: 1.81 min
# Epoch: 008/100 | Batch 0000/0032 | Loss: 3.7917
# Epoch: 008/100 | Train: 24.93% | Validation: 28.41%
# Time elapsed: 2.07 min
# Epoch: 009/100 | Batch 0000/0032 | Loss: 3.6105
# Epoch: 009/100 | Train: 24.58% | Validation: 28.64%
# Time elapsed: 2.32 min
# Epoch: 010/100 | Batch 0000/0032 | Loss: 3.6548
# Epoch: 010/100 | Train: 27.44% | Validation: 30.95%
# Time elapsed: 2.57 min
# Epoch: 011/100 | Batch 0000/0032 | Loss: 3.4448
# Epoch: 011/100 | Train: 28.03% | Validation: 31.87%
# Time elapsed: 2.83 min
# Epoch: 012/100 | Batch 0000/0032 | Loss: 3.2547
# Epoch: 012/100 | Train: 29.83% | Validation: 33.49%
# Time elapsed: 3.08 min
# Epoch: 013/100 | Batch 0000/0032 | Loss: 3.1755
# Epoch: 013/100 | Train: 31.69% | Validation: 34.18%
# Time elapsed: 3.34 min
# Epoch: 014/100 | Batch 0000/0032 | Loss: 3.1073
# Epoch: 014/100 | Train: 33.09% | Validation: 36.72%
# Time elapsed: 3.59 min
# Epoch: 015/100 | Batch 0000/0032 | Loss: 3.2220
# Epoch: 015/100 | Train: 35.36% | Validation: 38.11%
# Time elapsed: 8.63 min
# Epoch: 035/100 | Batch 0000/0032 | Loss: 1.6495
# Epoch: 035/100 | Train: 58.28% | Validation: 52.89%
# Time elapsed: 8.89 min
# Epoch: 036/100 | Batch 0000/0032 | Loss: 1.7962
# Epoch: 036/100 | Train: 59.48% | Validation: 52.66%
# Time elapsed: 9.14 min
# Epoch: 037/100 | Batch 0000/0032 | Loss: 1.7016
# Epoch: 037/100 | Train: 60.34% | Validation: 52.19%
# Time elapsed: 9.39 min
# Epoch: 038/100 | Batch 0000/0032 | Loss: 1.6325
# Epoch: 038/100 | Train: 61.08% | Validation: 52.19%
# Time elapsed: 9.64 min
# Epoch: 039/100 | Batch 0000/0032 | Loss: 1.6812
# Epoch: 039/100 | Train: 62.17% | Validation: 52.66%
# Time elapsed: 9.89 min
# Epoch: 040/100 | Batch 0000/0032 | Loss: 1.3764
# Epoch: 040/100 | Train: 63.53% | Validation: 54.04%
# Time elapsed: 10.14 min
# Epoch: 041/100 | Batch 0000/0032 | Loss: 1.5515
# Epoch: 041/100 | Train: 64.62% | Validation: 52.19%
# Time elapsed: 10.39 min
# Epoch: 042/100 | Batch 0000/0032 | Loss: 1.2416
# Epoch: 042/100 | Train: 64.75% | Validation: 51.96%
# Time elapsed: 10.64 min
# Epoch: 043/100 | Batch 0000/0032 | Loss: 1.4827
# Epoch: 043/100 | Train: 67.61% | Validation: 52.66%
# Time elapsed: 10.89 min
# Epoch: 044/100 | Batch 0000/0032 | Loss: 1.3758
# Epoch: 044/100 | Train: 68.33% | Validation: 53.58%
# Time elapsed: 11.15 min
# Epoch: 045/100 | Batch 0000/0032 | Loss: 1.4673
# Epoch: 045/100 | Train: 68.65% | Validation: 52.66%
# Time elapsed: 11.39 min
# Epoch: 046/100 | Batch 0000/0032 | Loss: 1.1829
# Epoch: 046/100 | Train: 70.09% | Validation: 52.89%
# Time elapsed: 11.65 min
# Epoch: 047/100 | Batch 0000/0032 | Loss: 1.2089
# Epoch: 047/100 | Train: 71.39% | Validation: 54.73%
# Time elapsed: 11.90 min
# Epoch: 048/100 | Batch 0000/0032 | Loss: 1.0629
# Epoch: 048/100 | Train: 71.53% | Validation: 53.81%
# Time elapsed: 12.15 min
# Epoch: 049/100 | Batch 0000/0032 | Loss: 1.2578
# Epoch: 049/100 | Train: 71.62% | Validation: 53.12%
# Time elapsed: 12.41 min
# Epoch: 050/100 | Batch 0000/0032 | Loss: 1.1888
# Epoch: 050/100 | Train: 71.97% | Validation: 53.58%
# Time elapsed: 12.66 min
# Epoch: 051/100 | Batch 0000/0032 | Loss: 1.2063
# Epoch: 051/100 | Train: 72.19% | Validation: 53.35%
# Time elapsed: 12.91 min
# Epoch: 052/100 | Batch 0000/0032 | Loss: 1.2884
# Epoch: 052/100 | Train: 72.39% | Validation: 53.35%
# Time elapsed: 13.16 min
# Epoch: 053/100 | Batch 0000/0032 | Loss: 1.1011
# Epoch: 053/100 | Train: 72.69% | Validation: 54.04%
# Epoch: 072/100 | Train: 72.62% | Validation: 54.50%
# Time elapsed: 18.19 min
# Epoch: 073/100 | Batch 0000/0032 | Loss: 1.2052
# Epoch: 073/100 | Train: 72.57% | Validation: 54.50%
# Time elapsed: 18.44 min
# Epoch: 074/100 | Batch 0000/0032 | Loss: 1.0966
# Epoch: 074/100 | Train: 72.61% | Validation: 54.50%
# Time elapsed: 18.69 min
# Epoch: 075/100 | Batch 0000/0032 | Loss: 1.0913
# Epoch: 075/100 | Train: 72.61% | Validation: 54.50%
# Time elapsed: 18.95 min
# Epoch: 076/100 | Batch 0000/0032 | Loss: 1.0224
# Epoch: 076/100 | Train: 72.67% | Validation: 54.50%
# Time elapsed: 19.20 min
# Epoch: 077/100 | Batch 0000/0032 | Loss: 1.1258
# Epoch: 077/100 | Train: 72.63% | Validation: 54.50%
# Time elapsed: 19.45 min
# Epoch: 078/100 | Batch 0000/0032 | Loss: 1.1720
# Epoch: 078/100 | Train: 72.58% | Validation: 54.50%
# Time elapsed: 19.70 min
# Epoch: 079/100 | Batch 0000/0032 | Loss: 1.1367
# Epoch: 079/100 | Train: 72.57% | Validation: 54.50%
# Time elapsed: 19.95 min
# Epoch: 080/100 | Batch 0000/0032 | Loss: 1.2690
# Epoch: 080/100 | Train: 72.64% | Validation: 54.50%
# Time elapsed: 20.20 min
# Epoch: 081/100 | Batch 0000/0032 | Loss: 1.1230
# Epoch: 081/100 | Train: 72.62% | Validation: 54.50%
# Time elapsed: 20.45 min
# Epoch: 082/100 | Batch 0000/0032 | Loss: 1.0937
# Epoch: 082/100 | Train: 72.66% | Validation: 54.50%
# Time elapsed: 20.71 min
# Epoch: 083/100 | Batch 0000/0032 | Loss: 1.1238
# Epoch: 083/100 | Train: 72.58% | Validation: 54.50%
# Time elapsed: 20.96 min
# Epoch: 084/100 | Batch 0000/0032 | Loss: 1.1392
# Epoch: 084/100 | Train: 72.69% | Validation: 54.50%
# Time elapsed: 21.20 min
# Epoch: 085/100 | Batch 0000/0032 | Loss: 1.1725
# Epoch: 085/100 | Train: 72.63% | Validation: 54.50%
# Time elapsed: 21.45 min
# Epoch: 086/100 | Batch 0000/0032 | Loss: 1.0158
# Epoch: 086/100 | Train: 72.63% | Validation: 54.50%
# Time elapsed: 21.69 min
# Epoch: 087/100 | Batch 0000/0032 | Loss: 1.2010
# Epoch: 087/100 | Train: 72.58% | Validation: 54.50%
# Time elapsed: 21.93 min
# Epoch: 088/100 | Batch 0000/0032 | Loss: 1.2633
# Epoch: 088/100 | Train: 72.67% | Validation: 54.50%
# Time elapsed: 22.18 min
# Epoch: 089/100 | Batch 0000/0032 | Loss: 1.0548
# Epoch: 089/100 | Train: 72.62% | Validation: 54.50%
# Time elapsed: 22.42 min
# Epoch: 090/100 | Batch 0000/0032 | Loss: 1.1290
# Epoch: 090/100 | Train: 72.63% | Validation: 54.50%
# Time elapsed: 22.66 min
# Epoch: 091/100 | Batch 0000/0032 | Loss: 1.2158
# Epoch: 091/100 | Train: 72.63% | Validation: 54.50%
# Time elapsed: 22.91 min
# Epoch: 092/100 | Batch 0000/0032 | Loss: 1.0637
# Epoch: 092/100 | Train: 72.67% | Validation: 54.50%
# Time elapsed: 23.15 min
# Epoch: 093/100 | Batch 0000/0032 | Loss: 1.2442
# Epoch: 093/100 | Train: 72.64% | Validation: 54.50%
# Time elapsed: 23.39 min
# Epoch: 094/100 | Batch 0000/0032 | Loss: 1.1674
# Epoch: 094/100 | Train: 72.64% | Validation: 54.50%
# Time elapsed: 23.63 min
# Epoch: 095/100 | Batch 0000/0032 | Loss: 1.1121
# Epoch: 095/100 | Train: 72.64% | Validation: 54.50%
# Time elapsed: 23.88 min
# Epoch: 096/100 | Batch 0000/0032 | Loss: 1.1877
# Epoch: 096/100 | Train: 72.53% | Validation: 54.50%
# Time elapsed: 24.12 min
# Epoch: 097/100 | Batch 0000/0032 | Loss: 1.0897
# Epoch: 097/100 | Train: 72.67% | Validation: 54.50%
# Time elapsed: 24.35 min
# Epoch: 098/100 | Batch 0000/0032 | Loss: 1.1555
# Epoch: 098/100 | Train: 72.71% | Validation: 54.50%
# Time elapsed: 24.59 min
# Epoch: 099/100 | Batch 0000/0032 | Loss: 1.2627
# Epoch: 099/100 | Train: 72.62% | Validation: 54.50%
# Time elapsed: 24.83 min
# Epoch: 100/100 | Batch 0000/0032 | Loss: 0.9809
# Epoch: 100/100 | Train: 72.61% | Validation: 54.50%
# Time elapsed: 25.07 min
# Total Training Time: 25.07 min
# Test accuracy 71.72%

# %%
from torchsummary import summary

summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1             [-1, 64, 7, 7]          23,296
#               Tanh-2             [-1, 64, 7, 7]               0
#          MaxPool2d-3             [-1, 64, 3, 3]               0
#             Conv2d-4            [-1, 192, 3, 3]         307,392
#               Tanh-5            [-1, 192, 3, 3]               0
#          MaxPool2d-6            [-1, 192, 1, 1]               0
#             Conv2d-7            [-1, 384, 1, 1]         663,936
#               Tanh-8            [-1, 384, 1, 1]               0
#          MaxPool2d-9            [-1, 384, 1, 1]               0
#            Linear-10                  [-1, 512]         197,120
#              Tanh-11                  [-1, 512]               0
#            Linear-12                  [-1, 101]          51,813
# ================================================================
# Total params: 1,243,557
# Trainable params: 1,243,557
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.10
# Params size (MB): 4.74
# Estimated Total Size (MB): 4.85
# ----------------------------------------------------------------

# %%
##########################
### SAVE MODEL
##########################
model.to(torch.device('cpu'))
os.makedirs('./models/cnn2-baseline', exist_ok=True)
torch.save(model.state_dict(), './models/cnn2-baseline/cnn2-baseline.pt')
torch.save(optimizer.state_dict(), './models/cnn2-baseline/cnn2-baseline-optimizer.pt')
torch.save(scheduler.state_dict(), './models/cnn2-baseline/cnn2-baseline-scheduler.pt')
