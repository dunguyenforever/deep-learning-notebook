# %%
import yaml
import argparse
import os
import sys
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Go up 1 directory level to import the helpers foldes
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# From local helper files
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helpers.helper_dataset import get_dataloaders_caltech101

# %%
##########################
### SETTINGS
##########################
parser = argparse.ArgumentParser()
script_dir = os.path.dirname(os.path.abspath('cnn1-baseline.ipynb'))
default_yaml = os.path.join(script_dir, 'config-baseline.yaml')
parser.add_argument('--settings_path',
                    type=str,
                    default=default_yaml,
                    help='Path to the YAML config file')

args, unknown = parser.parse_known_args() # Ignore unknown arguments

# Load YAML settings
with open(args.settings_path, 'r') as file:
    SETTINGS = yaml.load(file, Loader=yaml.FullLoader)

if torch.cuda.is_available():
    DEVICE = torch.device(f"cuda:{SETTINGS.get('cuda_device', 0)}")
else:
    DEVICE = torch.device('cpu')

# Set random seeds, etc.
set_all_seeds(SETTINGS['random_seed'])
# set_deterministic

# %%
##########################
### DATASET & DATALOADERS
##########################
resize_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((32, 32)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_loader, valid_loader, test_loader = get_dataloaders_caltech101(
    batch_size=SETTINGS['batch_size'],
    validation_fraction=SETTINGS['validation_percent'],
    train_transforms=resize_transform,
    test_transforms=resize_transform
)

##########################
### MODEL DEFINITION
##########################

class myCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # (1) 1st Convolutional Layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=11, stride=4, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride =2)
        )

        # (2) 2nd Convolutional Layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=5, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (3) 3rd Convolutional Layer
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=192, out_channels=384, kernel_size=3, padding=1),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=1, stride=1)
        )

        # (4) 4th Convolutional Layer
        self.conv4 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=1, stride=1)
        )

        # (4) Fully Connected Layers + Activation
        self.fc1 = nn.Sequential(
            nn.Linear(256 * 1 * 1, 512),
            nn.Tanh(),
            nn.Linear(512, num_classes)
        )

    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x


model = myCNN(num_classes=SETTINGS['num_classes'])
model.to(SETTINGS['cuda_device'])


##########################
### WEIGHT INITIALIZATION
##########################
def apply_weight_init(model, init_name='none'):
    """
    Apply weight initialization to Conv2d and Linear layers
    within an nn.Sequential model.
    """
    for layer in model.modules():
        if isinstance(layer, (nn.Conv2d, nn.Linear)):
            if init_name == 'xavier_uniform':
                nn.init.xavier_uniform_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'kaiming_normal':
                nn.init.kaiming_normal_(layer.weight, nonlinearity='relu')
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'orthogonal':
                nn.init.orthogonal_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            else:
                # If none or unknown, just leave PyTorch default
                pass

# Read weight init scheme from config
weight_init_config = SETTINGS.get('weight_init', {})
weight_init_name = weight_init_config.get('name', 'none')

apply_weight_init(model, init_name=weight_init_name)

##########################
### OPTIMIZER
##########################
optimizer_config = SETTINGS.get('optimizer', {})
optimizer_name = optimizer_config.get('name', 'Adam') # Default to Adam

weight_decay = float(optimizer_config.get('weight_decay', 0.0))
momentum = float(optimizer_config.get('momentum', 0.0)) # Default momentum for SGD
alpha = float(optimizer_config.get('alpha', 0.99)) # Default alpha for RMSprop

if optimizer_name == 'Adam':
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        weight_decay=weight_decay
    )
    
elif optimizer_name == 'SGD':
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay
    )

elif optimizer_name == 'RMSprop':
    optimizer = torch.optim.RMSProp(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay,
        alpha=alpha
    )

else:
    raise ValueError(f"Unknown optimizer: {optimizer_name}")

##########################
### LR SCHEDULER
##########################
scheduler_config = SETTINGS.get('scheduler', {})
scheduler_name = scheduler_config.get('name', 'None')

# Default to ReduceLROnPlateau, if not specified
if scheduler_name == 'ReduceLROnPlateau':
    factor = scheduler_config.get('factor', 0.1)
    mode = scheduler_config.get('mode', 'max')
    patience = scheduler_config.get('patience', 5)
    verbose = scheduler_config.get('verbose', True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        factor=factor,
        mode=mode,
        patience=patience
    )
elif scheduler_name == 'ExponentialLR':
    gamma = scheduler_config.get('gamma', 0.99)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name == 'StepLR':
    step_size = scheduler_config.get('step_size', 30)
    gamma = scheduler_config.get('gamma', 0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name.lower() == 'none':
    scheduler = None
else:
    raise ValueError(f"Unknown scheduler: {scheduler_name}")
# Out:
# Files already downloaded and verified

# %%
##########################
### TRAINING LOOP
##########################
# The helper_train.py presumably expects scheduler if not None,
# and you might specify how it’s applied (e.g., 'valid_acc').
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=SETTINGS['num_epochs'],
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=SETTINGS['cuda_device'],
    logging_interval=100,
    scheduler=scheduler,
    scheduler_on='valid_acc'  # or 'train_acc' or 'valid_loss'
)

##########################
### PLOTTING
##########################
plot_training_loss(
    minibatch_loss_list=minibatch_loss_list,
    num_epochs=SETTINGS['num_epochs'],
    iter_per_epoch=len(train_loader),
    results_dir=None,
    averaging_iterations=100
)
plt.show()

plot_accuracy(
    train_acc_list=train_acc_list,
    valid_acc_list=valid_acc_list,
    results_dir=None
)
plt.ylim([0, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0032 | Loss: 4.6143
# Epoch: 001/100 | Train: 9.07% | Validation: 11.55%
# Time elapsed: 0.27 min
# Epoch: 002/100 | Batch 0000/0032 | Loss: 4.5638
# Epoch: 002/100 | Train: 9.09% | Validation: 11.55%
# Time elapsed: 0.51 min
# Epoch: 003/100 | Batch 0000/0032 | Loss: 4.4436
# Epoch: 003/100 | Train: 9.12% | Validation: 11.55%
# Time elapsed: 0.76 min
# Epoch: 004/100 | Batch 0000/0032 | Loss: 4.3003
# Epoch: 004/100 | Train: 14.34% | Validation: 19.86%
# Time elapsed: 1.01 min
# Epoch: 005/100 | Batch 0000/0032 | Loss: 4.2950
# Epoch: 005/100 | Train: 7.54% | Validation: 8.31%
# Time elapsed: 1.25 min
# Epoch: 006/100 | Batch 0000/0032 | Loss: 4.1541
# Epoch: 006/100 | Train: 11.68% | Validation: 14.09%
# Time elapsed: 1.50 min
# Epoch: 007/100 | Batch 0000/0032 | Loss: 4.1987
# Epoch: 007/100 | Train: 9.23% | Validation: 11.55%
# Time elapsed: 1.75 min
# Epoch: 008/100 | Batch 0000/0032 | Loss: 4.0997
# Epoch: 008/100 | Train: 16.24% | Validation: 21.25%
# Time elapsed: 1.99 min
# Epoch: 009/100 | Batch 0000/0032 | Loss: 4.2447
# Epoch: 009/100 | Train: 15.06% | Validation: 20.09%
# Time elapsed: 2.24 min
# Epoch: 010/100 | Batch 0000/0032 | Loss: 4.0299
# Epoch: 010/100 | Train: 18.60% | Validation: 23.33%
# Time elapsed: 2.48 min
# Epoch: 011/100 | Batch 0000/0032 | Loss: 3.9004
# Epoch: 011/100 | Train: 20.96% | Validation: 25.64%
# Time elapsed: 2.73 min
# Epoch: 012/100 | Batch 0000/0032 | Loss: 3.9340
# Epoch: 012/100 | Train: 21.95% | Validation: 27.25%
# Time elapsed: 2.97 min
# Epoch: 013/100 | Batch 0000/0032 | Loss: 3.7715
# Epoch: 013/100 | Train: 23.36% | Validation: 28.18%
# Time elapsed: 3.22 min
# Epoch: 014/100 | Batch 0000/0032 | Loss: 3.7292
# Epoch: 014/100 | Train: 24.39% | Validation: 30.02%
# Time elapsed: 3.46 min
# Epoch: 015/100 | Batch 0000/0032 | Loss: 3.7553
# Epoch: 015/100 | Train: 26.25% | Validation: 30.72%
# Time elapsed: 3.71 min
# Epoch: 016/100 | Batch 0000/0032 | Loss: 3.5231
# Epoch: 016/100 | Train: 27.56% | Validation: 32.33%
# Time elapsed: 3.95 min
# Epoch: 017/100 | Batch 0000/0032 | Loss: 3.4158
# Epoch: 017/100 | Train: 28.66% | Validation: 33.03%
# Time elapsed: 4.20 min
# Epoch: 018/100 | Batch 0000/0032 | Loss: 3.2213
# Epoch: 018/100 | Train: 29.14% | Validation: 33.72%
# Time elapsed: 4.45 min
# Epoch: 019/100 | Batch 0000/0032 | Loss: 3.3255
# Epoch: 019/100 | Train: 30.81% | Validation: 35.10%
# Time elapsed: 4.69 min
# Epoch: 020/100 | Batch 0000/0032 | Loss: 3.1973
# Epoch: 020/100 | Train: 32.12% | Validation: 35.33%
# Time elapsed: 4.94 min
# Epoch: 021/100 | Batch 0000/0032 | Loss: 3.1498
# Epoch: 021/100 | Train: 33.86% | Validation: 36.49%
# Time elapsed: 5.19 min
# Epoch: 022/100 | Batch 0000/0032 | Loss: 2.8254
# Epoch: 022/100 | Train: 34.99% | Validation: 36.72%
# Time elapsed: 5.43 min
# Epoch: 023/100 | Batch 0000/0032 | Loss: 3.0682
# Epoch: 023/100 | Train: 35.42% | Validation: 37.18%
# Time elapsed: 5.68 min
# Epoch: 024/100 | Batch 0000/0032 | Loss: 2.8260
# Epoch: 024/100 | Train: 36.95% | Validation: 37.64%
# Time elapsed: 5.94 min
# Epoch: 025/100 | Batch 0000/0032 | Loss: 2.5191
# Epoch: 025/100 | Train: 37.11% | Validation: 38.34%
# Time elapsed: 6.19 min
# Epoch: 026/100 | Batch 0000/0032 | Loss: 2.8750
# Epoch: 026/100 | Train: 38.59% | Validation: 38.34%
# Time elapsed: 6.44 min
# Epoch: 027/100 | Batch 0000/0032 | Loss: 2.8563
# Epoch: 027/100 | Train: 38.64% | Validation: 38.80%
# Time elapsed: 6.69 min
# Epoch: 028/100 | Batch 0000/0032 | Loss: 2.5881
# Epoch: 028/100 | Train: 40.32% | Validation: 39.95%
# Time elapsed: 6.94 min
# Epoch: 029/100 | Batch 0000/0032 | Loss: 2.6049
# Epoch: 029/100 | Train: 40.41% | Validation: 40.18%
# Time elapsed: 7.18 min
# Epoch: 030/100 | Batch 0000/0032 | Loss: 2.6982
# Epoch: 030/100 | Train: 41.86% | Validation: 40.42%
# Time elapsed: 7.43 min
# Epoch: 031/100 | Batch 0000/0032 | Loss: 2.6334
# Epoch: 031/100 | Train: 42.21% | Validation: 39.26%
# Time elapsed: 7.68 min
# Epoch: 032/100 | Batch 0000/0032 | Loss: 2.4490
# Epoch: 032/100 | Train: 44.25% | Validation: 39.49%
# Time elapsed: 7.93 min
# Epoch: 033/100 | Batch 0000/0032 | Loss: 2.3995
# Epoch: 033/100 | Train: 43.87% | Validation: 41.80%
# Time elapsed: 8.18 min
# Epoch: 034/100 | Batch 0000/0032 | Loss: 2.2179
# Epoch: 092/100 | Batch 0000/0032 | Loss: 1.2092
# Epoch: 092/100 | Train: 70.56% | Validation: 46.19%
# Time elapsed: 22.95 min
# Epoch: 093/100 | Batch 0000/0032 | Loss: 1.0597
# Epoch: 093/100 | Train: 70.53% | Validation: 46.19%
# Time elapsed: 23.20 min
# Epoch: 094/100 | Batch 0000/0032 | Loss: 1.0679
# Epoch: 094/100 | Train: 70.54% | Validation: 46.19%
# Time elapsed: 23.45 min
# Epoch: 095/100 | Batch 0000/0032 | Loss: 1.1662
# Epoch: 095/100 | Train: 70.50% | Validation: 46.19%
# Time elapsed: 23.70 min
# Epoch: 096/100 | Batch 0000/0032 | Loss: 1.1081
# Epoch: 096/100 | Train: 70.63% | Validation: 46.19%
# Time elapsed: 23.95 min
# Epoch: 097/100 | Batch 0000/0032 | Loss: 1.2576
# Epoch: 097/100 | Train: 70.57% | Validation: 46.19%
# Time elapsed: 24.20 min
# Epoch: 098/100 | Batch 0000/0032 | Loss: 1.1631
# Epoch: 098/100 | Train: 70.54% | Validation: 46.19%
# Time elapsed: 24.44 min
# Epoch: 099/100 | Batch 0000/0032 | Loss: 1.1175
# Epoch: 099/100 | Train: 70.57% | Validation: 46.19%
# Time elapsed: 24.69 min
# Epoch: 100/100 | Batch 0000/0032 | Loss: 1.1953
# Epoch: 100/100 | Train: 70.61% | Validation: 46.19%
# Time elapsed: 24.94 min
# Total Training Time: 24.94 min
# Test accuracy 69.34%

# %%
from torchsummary import summary

summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1             [-1, 64, 7, 7]          23,296
#               Tanh-2             [-1, 64, 7, 7]               0
#          MaxPool2d-3             [-1, 64, 3, 3]               0
#             Conv2d-4            [-1, 192, 3, 3]         307,392
#               Tanh-5            [-1, 192, 3, 3]               0
#          MaxPool2d-6            [-1, 192, 1, 1]               0
#             Conv2d-7            [-1, 384, 1, 1]         663,936
#               Tanh-8            [-1, 384, 1, 1]               0
#          MaxPool2d-9            [-1, 384, 1, 1]               0
#            Conv2d-10            [-1, 256, 1, 1]         884,992
#              Tanh-11            [-1, 256, 1, 1]               0
#         MaxPool2d-12            [-1, 256, 1, 1]               0
#            Linear-13                  [-1, 512]         131,584
#              Tanh-14                  [-1, 512]               0
#            Linear-15                  [-1, 101]          51,813
# ================================================================
# Total params: 2,063,013
# Trainable params: 2,063,013
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.10
# Params size (MB): 7.87
# Estimated Total Size (MB): 7.98
# ----------------------------------------------------------------

# %%
##########################
### SAVE MODEL
##########################
model.to(torch.device('cpu'))
os.makedirs('./models/cnn3-baseline', exist_ok=True)
torch.save(model.state_dict(), './models/cnn3-baseline/cnn3-baseline.pt')
torch.save(optimizer.state_dict(), './models/cnn3-baseline/cnn3-baseline-optimizer.pt')
torch.save(scheduler.state_dict(), './models/cnn3-baseline/cnn3-baseline-scheduler.pt')
