# %%
import yaml
import argparse
import os
import sys
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Go up 1 directory level to import the helpers foldes
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# From local helper files
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helpers.helper_dataset import get_dataloaders_caltech101

# %%
##########################
### SETTINGS
##########################
parser = argparse.ArgumentParser()
script_dir = os.path.dirname(os.path.abspath('cnn1-v3.ipynb'))
default_yaml = os.path.join(script_dir, 'config-v3.yaml')
parser.add_argument('--settings_path',
                    type=str,
                    default=default_yaml,
                    help='Path to the YAML config file')

args, unknown = parser.parse_known_args() # Ignore unknown arguments

# Load YAML settings
with open(args.settings_path, 'r') as file:
    SETTINGS = yaml.load(file, Loader=yaml.FullLoader)

if torch.cuda.is_available():
    DEVICE = torch.device(f"cuda:{SETTINGS.get('cuda_device', 0)}")
else:
    DEVICE = torch.device('cpu')

# Set random seeds, etc.
set_all_seeds(SETTINGS['random_seed'])
# set_deterministic

# %%
##########################
### DATASET & DATALOADERS
##########################
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((200, 200)),
    torchvision.transforms.RandomCrop((128, 128)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((200, 200)),
    torchvision.transforms.CenterCrop((128, 128)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_loader, valid_loader, test_loader = get_dataloaders_caltech101(
    batch_size=SETTINGS['batch_size'],
    validation_fraction=SETTINGS['validation_percent'],
    train_transforms=train_transform,
    test_transforms=test_transform
)

##########################
### MODEL DEFINITION
##########################

class myCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # (1) 1st Convolutional Layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=11, stride=4, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride =2)
        )

        # (2) 2nd Convolutional Layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=5, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (3) 3rd Convolutional Layer
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=192, out_channels=384, kernel_size=3, padding=1),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (4) Fully Connected Layers + Activation
        self.fc1 = nn.Sequential(
            nn.Linear(384 * 3 * 3, 512),
            nn.Tanh(),
            nn.Linear(512, num_classes)
        )

    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x


model = myCNN(num_classes=SETTINGS['num_classes'])
model.to(SETTINGS['cuda_device'])


##########################
### WEIGHT INITIALIZATION
##########################
def apply_weight_init(model, init_name='none'):
    """
    Apply weight initialization to Conv2d and Linear layers
    within an nn.Sequential model.
    """
    for layer in model.modules():
        if isinstance(layer, (nn.Conv2d, nn.Linear)):
            if init_name == 'xavier_uniform':
                nn.init.xavier_uniform_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'kaiming_normal':
                nn.init.kaiming_normal_(layer.weight, nonlinearity='relu')
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'orthogonal':
                nn.init.orthogonal_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            else:
                # If none or unknown, just leave PyTorch default
                pass

# Read weight init scheme from config
weight_init_config = SETTINGS.get('weight_init', {})
weight_init_name = weight_init_config.get('name', 'none')

apply_weight_init(model, init_name=weight_init_name)

##########################
### OPTIMIZER
##########################
optimizer_config = SETTINGS.get('optimizer', {})
optimizer_name = optimizer_config.get('name', 'Adam') # Default to Adam

weight_decay = float(optimizer_config.get('weight_decay', 0.0))
momentum = float(optimizer_config.get('momentum', 0.0)) # Default momentum for SGD


if optimizer_name == 'Adam':
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        weight_decay=weight_decay
    )
    
elif optimizer_name == 'SGD':
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay
    )

elif optimizer_name == 'RMSprop':
    alpha = float(optimizer_config.get('alpha', 0.99)) # Default alpha for RMSprop
    eps = float(optimizer_config.get('eps', 1e-8))
    optimizer = torch.optim.RMSprop(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay,
        alpha=alpha
    )

else:
    raise ValueError(f"Unknown optimizer: {optimizer_name}")

##########################
### LR SCHEDULER
##########################
scheduler_config = SETTINGS.get('scheduler', {})
scheduler_name = scheduler_config.get('name', 'None')

# Default to ReduceLROnPlateau, if not specified
if scheduler_name == 'ReduceLROnPlateau':
    factor = scheduler_config.get('factor', 0.1)
    mode = scheduler_config.get('mode', 'max')
    patience = scheduler_config.get('patience', 5)
    verbose = scheduler_config.get('verbose', True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        factor=factor,
        mode=mode,
        patience=patience
    )
elif scheduler_name == 'ExponentialLR':
    gamma = scheduler_config.get('gamma', 0.99)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name == 'StepLR':
    step_size = scheduler_config.get('step_size', 30)
    gamma = scheduler_config.get('gamma', 0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name.lower() == 'none':
    scheduler = None
else:
    raise ValueError(f"Unknown scheduler: {scheduler_name}")
# Out:
# Files already downloaded and verified

# %%
##########################
### TRAINING LOOP
##########################
# The helper_train.py presumably expects scheduler if not None,
# and you might specify how it’s applied (e.g., 'valid_acc').
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=SETTINGS['num_epochs'],
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=SETTINGS['cuda_device'],
    logging_interval=100,
    scheduler=scheduler,
    scheduler_on='valid_acc'  # or 'train_acc' or 'valid_loss'
)

##########################
### PLOTTING
##########################
plot_training_loss(
    minibatch_loss_list=minibatch_loss_list,
    num_epochs=SETTINGS['num_epochs'],
    iter_per_epoch=len(train_loader),
    results_dir=None,
    averaging_iterations=100
)
plt.show()

plot_accuracy(
    train_acc_list=train_acc_list,
    valid_acc_list=valid_acc_list,
    results_dir=None
)
plt.ylim([0, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0032 | Loss: 4.6076
# Epoch: 001/100 | Train: 15.93% | Validation: 18.24%
# Time elapsed: 0.68 min
# Epoch: 002/100 | Batch 0000/0032 | Loss: 4.0860
# Epoch: 002/100 | Train: 18.49% | Validation: 22.17%
# Time elapsed: 1.38 min
# Epoch: 003/100 | Batch 0000/0032 | Loss: 3.8609
# Epoch: 003/100 | Train: 21.30% | Validation: 24.71%
# Time elapsed: 2.10 min
# Epoch: 004/100 | Batch 0000/0032 | Loss: 3.8840
# Epoch: 004/100 | Train: 23.68% | Validation: 28.64%
# Time elapsed: 2.73 min
# Epoch: 005/100 | Batch 0000/0032 | Loss: 3.6033
# Epoch: 005/100 | Train: 25.24% | Validation: 28.64%
# Time elapsed: 3.39 min
# Epoch: 006/100 | Batch 0000/0032 | Loss: 3.5846
# Epoch: 006/100 | Train: 26.62% | Validation: 29.79%
# Time elapsed: 4.00 min
# Epoch: 007/100 | Batch 0000/0032 | Loss: 3.3417
# Epoch: 007/100 | Train: 28.10% | Validation: 30.25%
# Time elapsed: 4.64 min
# Epoch: 008/100 | Batch 0000/0032 | Loss: 3.5150
# Epoch: 008/100 | Train: 28.85% | Validation: 30.48%
# Time elapsed: 5.22 min
# Epoch: 009/100 | Batch 0000/0032 | Loss: 3.3137
# Epoch: 009/100 | Train: 28.66% | Validation: 32.79%
# Time elapsed: 5.81 min
# Epoch: 010/100 | Batch 0000/0032 | Loss: 3.3706
# Epoch: 010/100 | Train: 30.31% | Validation: 33.49%
# Time elapsed: 6.41 min
# Epoch: 011/100 | Batch 0000/0032 | Loss: 3.0880
# Epoch: 011/100 | Train: 31.51% | Validation: 34.64%
# Time elapsed: 7.02 min
# Epoch: 012/100 | Batch 0000/0032 | Loss: 2.9928
# Epoch: 012/100 | Train: 33.06% | Validation: 36.26%
# Time elapsed: 7.62 min
# Epoch: 013/100 | Batch 0000/0032 | Loss: 3.0039
# Epoch: 013/100 | Train: 33.78% | Validation: 36.26%
# Time elapsed: 8.23 min
# Epoch: 014/100 | Batch 0000/0032 | Loss: 3.1452
# Epoch: 014/100 | Train: 32.53% | Validation: 36.03%
# Time elapsed: 8.82 min
# Epoch: 015/100 | Batch 0000/0032 | Loss: 3.0081
# Epoch: 015/100 | Train: 34.31% | Validation: 35.80%
# Time elapsed: 9.42 min
# Epoch: 016/100 | Batch 0000/0032 | Loss: 2.8868
# Epoch: 016/100 | Train: 35.84% | Validation: 41.34%
# Time elapsed: 10.02 min
# Epoch: 017/100 | Batch 0000/0032 | Loss: 2.9043
# Epoch: 017/100 | Train: 37.54% | Validation: 39.72%
# Time elapsed: 10.62 min
# Epoch: 018/100 | Batch 0000/0032 | Loss: 2.7324
# Epoch: 018/100 | Train: 37.55% | Validation: 42.73%
# Time elapsed: 11.23 min
# Epoch: 019/100 | Batch 0000/0032 | Loss: 2.8873
# Epoch: 019/100 | Train: 39.03% | Validation: 43.19%
# Time elapsed: 11.84 min
# Epoch: 020/100 | Batch 0000/0032 | Loss: 2.8583
# Epoch: 020/100 | Train: 39.15% | Validation: 44.11%
# Time elapsed: 12.44 min
# Epoch: 021/100 | Batch 0000/0032 | Loss: 2.6654
# Epoch: 021/100 | Train: 39.71% | Validation: 44.80%
# Time elapsed: 13.04 min
# Epoch: 022/100 | Batch 0000/0032 | Loss: 2.6655
# Epoch: 022/100 | Train: 40.88% | Validation: 43.65%
# Time elapsed: 13.65 min
# Epoch: 023/100 | Batch 0000/0032 | Loss: 2.8105
# Epoch: 023/100 | Train: 41.86% | Validation: 45.27%
# Time elapsed: 14.30 min
# Epoch: 024/100 | Batch 0000/0032 | Loss: 2.5589
# Epoch: 024/100 | Train: 42.96% | Validation: 45.27%
# Time elapsed: 14.91 min
# Epoch: 025/100 | Batch 0000/0032 | Loss: 2.4628
# Epoch: 025/100 | Train: 39.47% | Validation: 42.49%
# Time elapsed: 15.52 min
# Epoch: 026/100 | Batch 0000/0032 | Loss: 2.7575
# Epoch: 026/100 | Train: 44.25% | Validation: 46.19%
# Time elapsed: 16.13 min
# Epoch: 027/100 | Batch 0000/0032 | Loss: 2.3758
# Epoch: 027/100 | Train: 44.15% | Validation: 48.04%
# Time elapsed: 16.73 min
# Epoch: 028/100 | Batch 0000/0032 | Loss: 2.3304
# Epoch: 028/100 | Train: 45.17% | Validation: 49.19%
# Time elapsed: 17.37 min
# Epoch: 029/100 | Batch 0000/0032 | Loss: 2.5305
# Epoch: 029/100 | Train: 46.40% | Validation: 48.04%
# Time elapsed: 17.98 min
# Epoch: 030/100 | Batch 0000/0032 | Loss: 2.0751
# Epoch: 030/100 | Train: 45.86% | Validation: 47.81%
# Time elapsed: 18.57 min
# Epoch: 031/100 | Batch 0000/0032 | Loss: 2.2213
# Epoch: 031/100 | Train: 47.13% | Validation: 50.12%
# Time elapsed: 19.17 min
# Epoch: 032/100 | Batch 0000/0032 | Loss: 2.5124
# Epoch: 032/100 | Train: 46.67% | Validation: 46.65%
# Time elapsed: 19.77 min
# Epoch: 033/100 | Batch 0000/0032 | Loss: 2.3623
# Epoch: 033/100 | Train: 44.31% | Validation: 42.96%
# Time elapsed: 20.38 min
# Epoch: 034/100 | Batch 0000/0032 | Loss: 2.4821
# Epoch: 034/100 | Train: 46.89% | Validation: 48.04%
# Time elapsed: 20.97 min
# Epoch: 035/100 | Batch 0000/0032 | Loss: 2.2451
# Epoch: 035/100 | Train: 50.20% | Validation: 51.96%
# Time elapsed: 21.56 min
# Epoch: 036/100 | Batch 0000/0032 | Loss: 2.1999
# Epoch: 036/100 | Train: 48.65% | Validation: 48.96%
# Time elapsed: 22.14 min
# Epoch: 037/100 | Batch 0000/0032 | Loss: 2.2640
# Epoch: 037/100 | Train: 48.75% | Validation: 47.58%
# Time elapsed: 22.73 min
# Epoch: 038/100 | Batch 0000/0032 | Loss: 1.9387
# Epoch: 038/100 | Train: 50.83% | Validation: 51.04%
# Time elapsed: 23.32 min
# Epoch: 039/100 | Batch 0000/0032 | Loss: 2.1056
# Epoch: 039/100 | Train: 50.51% | Validation: 50.12%
# Time elapsed: 23.91 min
# Epoch: 040/100 | Batch 0000/0032 | Loss: 2.1768
# Epoch: 040/100 | Train: 51.73% | Validation: 50.12%
# Time elapsed: 24.49 min
# Epoch: 041/100 | Batch 0000/0032 | Loss: 2.0116
# Epoch: 041/100 | Train: 51.09% | Validation: 51.27%
# Time elapsed: 25.08 min
# Epoch: 042/100 | Batch 0000/0032 | Loss: 1.9656
# Epoch: 042/100 | Train: 56.23% | Validation: 53.81%
# Time elapsed: 25.67 min
# Epoch: 043/100 | Batch 0000/0032 | Loss: 1.7030
# Epoch: 043/100 | Train: 56.99% | Validation: 54.73%
# Time elapsed: 26.32 min
# Epoch: 044/100 | Batch 0000/0032 | Loss: 1.5941
# Epoch: 044/100 | Train: 57.48% | Validation: 54.50%
# Time elapsed: 27.04 min
# Epoch: 045/100 | Batch 0000/0032 | Loss: 1.7358
# Epoch: 045/100 | Train: 57.84% | Validation: 55.20%
# Time elapsed: 27.71 min
# Epoch: 046/100 | Batch 0000/0032 | Loss: 1.5965
# Epoch: 046/100 | Train: 58.50% | Validation: 54.73%
# Time elapsed: 28.35 min
# Epoch: 047/100 | Batch 0000/0032 | Loss: 1.7844
# Epoch: 047/100 | Train: 58.75% | Validation: 55.66%
# Time elapsed: 28.94 min
# Epoch: 048/100 | Batch 0000/0032 | Loss: 1.6073
# Epoch: 048/100 | Train: 58.41% | Validation: 54.97%
# Time elapsed: 29.54 min
# Epoch: 049/100 | Batch 0000/0032 | Loss: 1.7048
# Epoch: 049/100 | Train: 59.33% | Validation: 55.43%
# Time elapsed: 30.16 min
# Epoch: 050/100 | Batch 0000/0032 | Loss: 1.8454
# Epoch: 050/100 | Train: 59.64% | Validation: 55.43%
# Time elapsed: 30.76 min
# Epoch: 051/100 | Batch 0000/0032 | Loss: 1.6451
# Epoch: 051/100 | Train: 59.73% | Validation: 55.20%
# Time elapsed: 31.36 min
# Epoch: 052/100 | Batch 0000/0032 | Loss: 1.7698
# Epoch: 052/100 | Train: 60.67% | Validation: 55.66%
# Time elapsed: 31.95 min
# Epoch: 053/100 | Batch 0000/0032 | Loss: 1.5019
# Epoch: 053/100 | Train: 61.07% | Validation: 55.43%
# Time elapsed: 32.53 min
# Epoch: 054/100 | Batch 0000/0032 | Loss: 1.6449
# Epoch: 054/100 | Train: 60.90% | Validation: 55.66%
# Time elapsed: 33.12 min
# Epoch: 055/100 | Batch 0000/0032 | Loss: 1.5091
# Epoch: 055/100 | Train: 60.95% | Validation: 55.20%
# Time elapsed: 33.71 min
# Epoch: 056/100 | Batch 0000/0032 | Loss: 1.5834
# Epoch: 056/100 | Train: 60.57% | Validation: 55.43%
# Time elapsed: 34.29 min
# Epoch: 057/100 | Batch 0000/0032 | Loss: 1.6771
# Epoch: 057/100 | Train: 61.07% | Validation: 55.20%
# Time elapsed: 34.88 min
# Epoch: 058/100 | Batch 0000/0032 | Loss: 1.4732
# Epoch: 058/100 | Train: 60.58% | Validation: 55.43%
# Time elapsed: 35.47 min
# Epoch: 059/100 | Batch 0000/0032 | Loss: 1.6738
# Epoch: 059/100 | Train: 60.79% | Validation: 55.66%
# Time elapsed: 36.06 min
# Epoch: 060/100 | Batch 0000/0032 | Loss: 1.5879
# Epoch: 060/100 | Train: 60.85% | Validation: 55.66%
# Time elapsed: 36.65 min
# Epoch: 061/100 | Batch 0000/0032 | Loss: 1.5318
# Epoch: 061/100 | Train: 60.78% | Validation: 55.89%
# Time elapsed: 37.23 min
# Epoch: 062/100 | Batch 0000/0032 | Loss: 1.4556
# Epoch: 062/100 | Train: 61.04% | Validation: 55.89%
# Time elapsed: 38.03 min
# Epoch: 063/100 | Batch 0000/0032 | Loss: 1.7039
# Epoch: 063/100 | Train: 60.82% | Validation: 55.89%
# Time elapsed: 38.68 min
# Epoch: 064/100 | Batch 0000/0032 | Loss: 1.5361
# Epoch: 064/100 | Train: 61.00% | Validation: 55.89%
# Time elapsed: 39.35 min
# Epoch: 065/100 | Batch 0000/0032 | Loss: 1.6948
# Epoch: 065/100 | Train: 61.10% | Validation: 55.66%
# Time elapsed: 40.03 min
# Epoch: 066/100 | Batch 0000/0032 | Loss: 1.5716
# Epoch: 066/100 | Train: 59.99% | Validation: 55.89%
# Time elapsed: 40.72 min
# Epoch: 067/100 | Batch 0000/0032 | Loss: 1.6241
# Epoch: 067/100 | Train: 60.72% | Validation: 55.89%
# Time elapsed: 41.41 min
# Epoch: 068/100 | Batch 0000/0032 | Loss: 1.6230
# Epoch: 068/100 | Train: 60.72% | Validation: 55.89%
# Time elapsed: 42.08 min
# Epoch: 069/100 | Batch 0000/0032 | Loss: 1.5012
# Epoch: 069/100 | Train: 60.90% | Validation: 55.89%
# Time elapsed: 42.76 min
# Epoch: 070/100 | Batch 0000/0032 | Loss: 1.7408
# Epoch: 070/100 | Train: 60.47% | Validation: 55.89%
# Time elapsed: 43.46 min
# Epoch: 071/100 | Batch 0000/0032 | Loss: 1.5821
# Epoch: 071/100 | Train: 60.75% | Validation: 55.89%
# Time elapsed: 44.15 min
# Epoch: 072/100 | Batch 0000/0032 | Loss: 1.7090
# Epoch: 072/100 | Train: 60.86% | Validation: 55.89%
# Time elapsed: 44.83 min
# Epoch: 073/100 | Batch 0000/0032 | Loss: 1.5665
# Epoch: 073/100 | Train: 60.61% | Validation: 56.12%
# Time elapsed: 45.42 min
# Epoch: 074/100 | Batch 0000/0032 | Loss: 1.5117
# Epoch: 074/100 | Train: 60.56% | Validation: 55.89%
# Time elapsed: 45.98 min
# Epoch: 075/100 | Batch 0000/0032 | Loss: 1.5719
# Epoch: 075/100 | Train: 60.69% | Validation: 55.89%
# Time elapsed: 46.54 min
# Epoch: 076/100 | Batch 0000/0032 | Loss: 1.5774
# Epoch: 076/100 | Train: 60.38% | Validation: 55.89%
# Time elapsed: 47.10 min
# Epoch: 077/100 | Batch 0000/0032 | Loss: 1.5501
# Epoch: 077/100 | Train: 60.88% | Validation: 55.89%
# Time elapsed: 47.66 min
# Epoch: 078/100 | Batch 0000/0032 | Loss: 1.6297
# Epoch: 078/100 | Train: 60.86% | Validation: 55.89%
# Time elapsed: 48.21 min
# Epoch: 079/100 | Batch 0000/0032 | Loss: 1.7397
# Epoch: 079/100 | Train: 61.16% | Validation: 55.89%
# Time elapsed: 48.77 min
# Epoch: 080/100 | Batch 0000/0032 | Loss: 1.5528
# Epoch: 080/100 | Train: 61.25% | Validation: 55.89%
# Time elapsed: 49.34 min
# Epoch: 081/100 | Batch 0000/0032 | Loss: 1.6167
# Epoch: 081/100 | Train: 60.73% | Validation: 55.89%
# Time elapsed: 49.91 min
# Epoch: 082/100 | Batch 0000/0032 | Loss: 1.5952
# Epoch: 082/100 | Train: 60.58% | Validation: 55.89%
# Time elapsed: 50.47 min
# Epoch: 083/100 | Batch 0000/0032 | Loss: 1.6248
# Epoch: 083/100 | Train: 60.94% | Validation: 55.89%
# Time elapsed: 51.02 min
# Epoch: 084/100 | Batch 0000/0032 | Loss: 1.6602
# Epoch: 084/100 | Train: 60.64% | Validation: 55.89%
# Time elapsed: 51.58 min
# Epoch: 085/100 | Batch 0000/0032 | Loss: 1.4359
# Epoch: 085/100 | Train: 60.86% | Validation: 55.89%
# Time elapsed: 52.13 min
# Epoch: 086/100 | Batch 0000/0032 | Loss: 1.5120
# Epoch: 086/100 | Train: 60.11% | Validation: 55.89%
# Time elapsed: 52.69 min
# Epoch: 087/100 | Batch 0000/0032 | Loss: 1.5017
# Epoch: 087/100 | Train: 60.73% | Validation: 55.89%
# Time elapsed: 53.24 min
# Epoch: 088/100 | Batch 0000/0032 | Loss: 1.7157
# Epoch: 088/100 | Train: 61.23% | Validation: 55.89%
# Time elapsed: 53.79 min
# Epoch: 089/100 | Batch 0000/0032 | Loss: 1.6734
# Epoch: 089/100 | Train: 60.41% | Validation: 55.89%
# Time elapsed: 54.35 min
# Epoch: 090/100 | Batch 0000/0032 | Loss: 1.5430
# Epoch: 090/100 | Train: 60.18% | Validation: 55.89%
# Time elapsed: 54.90 min
# Epoch: 091/100 | Batch 0000/0032 | Loss: 1.6094
# Epoch: 091/100 | Train: 61.43% | Validation: 55.89%
# Time elapsed: 55.46 min
# Epoch: 092/100 | Batch 0000/0032 | Loss: 1.4910
# Epoch: 092/100 | Train: 60.55% | Validation: 55.89%
# Time elapsed: 56.01 min
# Epoch: 093/100 | Batch 0000/0032 | Loss: 1.6926
# Epoch: 093/100 | Train: 60.72% | Validation: 55.89%
# Time elapsed: 56.56 min
# Epoch: 094/100 | Batch 0000/0032 | Loss: 1.5088
# Epoch: 094/100 | Train: 61.08% | Validation: 55.89%
# Time elapsed: 57.12 min
# Epoch: 095/100 | Batch 0000/0032 | Loss: 1.6367
# Epoch: 095/100 | Train: 61.07% | Validation: 55.89%
# Time elapsed: 57.68 min
# Epoch: 096/100 | Batch 0000/0032 | Loss: 1.5882
# Epoch: 096/100 | Train: 60.31% | Validation: 55.89%
# Time elapsed: 58.23 min
# Epoch: 097/100 | Batch 0000/0032 | Loss: 1.7974
# Epoch: 097/100 | Train: 60.68% | Validation: 55.89%
# Time elapsed: 58.79 min
# Epoch: 098/100 | Batch 0000/0032 | Loss: 1.5221
# Epoch: 098/100 | Train: 60.78% | Validation: 55.89%
# Time elapsed: 59.34 min
# Epoch: 099/100 | Batch 0000/0032 | Loss: 1.6164
# Epoch: 099/100 | Train: 60.51% | Validation: 55.89%
# Time elapsed: 59.89 min
# Epoch: 100/100 | Batch 0000/0032 | Loss: 1.5642
# Epoch: 100/100 | Train: 60.62% | Validation: 55.89%
# Time elapsed: 60.52 min
# Total Training Time: 60.52 min
# Test accuracy 67.52%

# %%
from torchsummary import summary
summary(model, input_size=(3, 128, 128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 31, 31]          23,296
#               Tanh-2           [-1, 64, 31, 31]               0
#          MaxPool2d-3           [-1, 64, 15, 15]               0
#             Conv2d-4          [-1, 192, 15, 15]         307,392
#               Tanh-5          [-1, 192, 15, 15]               0
#          MaxPool2d-6            [-1, 192, 7, 7]               0
#             Conv2d-7            [-1, 384, 7, 7]         663,936
#               Tanh-8            [-1, 384, 7, 7]               0
#          MaxPool2d-9            [-1, 384, 3, 3]               0
#            Linear-10                  [-1, 512]       1,769,984
#              Tanh-11                  [-1, 512]               0
#            Linear-12                  [-1, 101]          51,813
# ================================================================
# Total params: 2,816,421
# Trainable params: 2,816,421
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 2.10
# Params size (MB): 10.74
# Estimated Total Size (MB): 13.03
# ----------------------------------------------------------------

# %%
##########################
### SAVE MODEL
##########################
model.to(torch.device('cpu'))
os.makedirs('./models/cnn2-v3', exist_ok=True)
torch.save(model.state_dict(), './models/cnn2-v3/cnn2-v3.pt')
torch.save(optimizer.state_dict(), './models/cnn2-v3/cnn2-v3-optimizer.pt')
torch.save(scheduler.state_dict(), './models/cnn2-v3/cnn2-v3-scheduler.pt')
