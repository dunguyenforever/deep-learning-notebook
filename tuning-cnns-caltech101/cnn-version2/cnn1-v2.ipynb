# %%
import yaml
import argparse
import os
import sys
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Go up 1 directory level to import the helpers foldes
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# From local helper files
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helpers.helper_dataset import get_dataloaders_caltech101

# %%
##########################
### SETTINGS
##########################
parser = argparse.ArgumentParser()
script_dir = os.path.dirname(os.path.abspath('cnn1-v2.ipynb'))
default_yaml = os.path.join(script_dir, 'config-v2.yaml')
parser.add_argument('--settings_path',
                    type=str,
                    default=default_yaml,
                    help='Path to the YAML config file')

args, unknown = parser.parse_known_args() # Ignore unknown arguments

# Load YAML settings
with open(args.settings_path, 'r') as file:
    SETTINGS = yaml.load(file, Loader=yaml.FullLoader)

if torch.cuda.is_available():
    DEVICE = torch.device(f"cuda:{SETTINGS.get('cuda_device', 0)}")
else:
    DEVICE = torch.device('cpu')

# Set random seeds, etc.
set_all_seeds(SETTINGS['random_seed'])
# set_deterministic

# %%
##########################
### DATASET & DATALOADERS
##########################
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((256, 256)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((256, 256)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_loader, valid_loader, test_loader = get_dataloaders_caltech101(
    batch_size=SETTINGS['batch_size'],
    validation_fraction=SETTINGS['validation_percent'],
    train_transforms=train_transform,
    test_transforms=test_transform
)

##########################
### MODEL DEFINITION
##########################

class myCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # (1) 1st Convolutional Layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=11, stride=4, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride =2)
        )

        # (2) 2nd Convolutional Layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=5, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (4) Fully Connected Layers + Activation
        self.fc1 = nn.Sequential(
            nn.Linear(192 * 15 * 15, 512),
            nn.Tanh(),
            nn.Linear(512, num_classes)
        )

    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x


model = myCNN(num_classes=SETTINGS['num_classes'])
model.to(SETTINGS['cuda_device'])


##########################
### WEIGHT INITIALIZATION
##########################
def apply_weight_init(model, init_name='none'):
    """
    Apply weight initialization to Conv2d and Linear layers
    within an nn.Sequential model.
    """
    for layer in model.modules():
        if isinstance(layer, (nn.Conv2d, nn.Linear)):
            if init_name == 'xavier_uniform':
                nn.init.xavier_uniform_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'kaiming_normal':
                nn.init.kaiming_normal_(layer.weight, nonlinearity='relu')
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'orthogonal':
                nn.init.orthogonal_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            else:
                # If none or unknown, just leave PyTorch default
                pass

# Read weight init scheme from config
weight_init_config = SETTINGS.get('weight_init', {})
weight_init_name = weight_init_config.get('name', 'none')

apply_weight_init(model, init_name=weight_init_name)

##########################
### OPTIMIZER
##########################
optimizer_config = SETTINGS.get('optimizer', {})
optimizer_name = optimizer_config.get('name', 'Adam') # Default to Adam

weight_decay = float(optimizer_config.get('weight_decay', 0.0))
momentum = float(optimizer_config.get('momentum', 0.0)) # Default momentum for SGD
alpha = float(optimizer_config.get('alpha', 0.99)) # Default alpha for RMSprop

if optimizer_name == 'Adam':
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        weight_decay=weight_decay
    )
    
elif optimizer_name == 'SGD':
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay
    )

elif optimizer_name == 'RMSprop':
    optimizer = torch.optim.RMSProp(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay,
        alpha=alpha
    )

else:
    raise ValueError(f"Unknown optimizer: {optimizer_name}")

##########################
### LR SCHEDULER
##########################
scheduler_config = SETTINGS.get('scheduler', {})
scheduler_name = scheduler_config.get('name', 'None')

# Default to ReduceLROnPlateau, if not specified
if scheduler_name == 'ReduceLROnPlateau':
    factor = scheduler_config.get('factor', 0.1)
    mode = scheduler_config.get('mode', 'max')
    patience = scheduler_config.get('patience', 5)
    verbose = scheduler_config.get('verbose', True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        factor=factor,
        mode=mode,
        patience=patience
    )
elif scheduler_name == 'ExponentialLR':
    gamma = scheduler_config.get('gamma', 0.99)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name == 'StepLR':
    step_size = scheduler_config.get('step_size', 30)
    gamma = scheduler_config.get('gamma', 0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name.lower() == 'none':
    scheduler = None
else:
    raise ValueError(f"Unknown scheduler: {scheduler_name}")
# Out:
# Files already downloaded and verified

# %%
##########################
### TRAINING LOOP
##########################
# The helper_train.py presumably expects scheduler if not None,
# and you might specify how it’s applied (e.g., 'valid_acc').
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=SETTINGS['num_epochs'],
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=SETTINGS['cuda_device'],
    logging_interval=100,
    scheduler=scheduler,
    scheduler_on='valid_acc'  # or 'train_acc' or 'valid_loss'
)

##########################
### PLOTTING
##########################
plot_training_loss(
    minibatch_loss_list=minibatch_loss_list,
    num_epochs=SETTINGS['num_epochs'],
    iter_per_epoch=len(train_loader),
    results_dir=None,
    averaging_iterations=100
)
plt.show()

plot_accuracy(
    train_acc_list=train_acc_list,
    valid_acc_list=valid_acc_list,
    results_dir=None
)
plt.ylim([0, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0032 | Loss: 4.6452
# Epoch: 001/100 | Train: 27.05% | Validation: 30.95%
# Time elapsed: 0.70 min
# Epoch: 002/100 | Batch 0000/0032 | Loss: 3.0568
# Epoch: 002/100 | Train: 38.67% | Validation: 39.26%
# Time elapsed: 1.42 min
# Epoch: 003/100 | Batch 0000/0032 | Loss: 2.4073
# Epoch: 003/100 | Train: 49.24% | Validation: 45.73%
# Time elapsed: 2.16 min
# Epoch: 004/100 | Batch 0000/0032 | Loss: 2.2673
# Epoch: 004/100 | Train: 56.63% | Validation: 50.58%
# Time elapsed: 2.91 min
# Epoch: 005/100 | Batch 0000/0032 | Loss: 1.8240
# Epoch: 005/100 | Train: 63.33% | Validation: 56.12%
# Time elapsed: 3.65 min
# Epoch: 006/100 | Batch 0000/0032 | Loss: 1.7283
# Epoch: 006/100 | Train: 67.74% | Validation: 57.97%
# Time elapsed: 4.38 min
# Epoch: 007/100 | Batch 0000/0032 | Loss: 1.3961
# Epoch: 007/100 | Train: 72.72% | Validation: 57.74%
# Time elapsed: 5.13 min
# Epoch: 008/100 | Batch 0000/0032 | Loss: 1.1528
# Epoch: 008/100 | Train: 77.12% | Validation: 62.36%
# Time elapsed: 5.87 min
# Epoch: 009/100 | Batch 0000/0032 | Loss: 0.9439
# Epoch: 009/100 | Train: 80.91% | Validation: 61.89%
# Time elapsed: 6.60 min
# Epoch: 010/100 | Batch 0000/0032 | Loss: 0.8166
# Epoch: 010/100 | Train: 84.20% | Validation: 63.74%
# Time elapsed: 7.33 min
# Epoch: 011/100 | Batch 0000/0032 | Loss: 0.7022
# Epoch: 011/100 | Train: 88.00% | Validation: 60.97%
# Time elapsed: 8.07 min
# Epoch: 012/100 | Batch 0000/0032 | Loss: 0.5845
# Epoch: 012/100 | Train: 89.82% | Validation: 62.12%
# Time elapsed: 8.80 min
# Epoch: 013/100 | Batch 0000/0032 | Loss: 0.4663
# Epoch: 013/100 | Train: 92.58% | Validation: 63.97%
# Time elapsed: 9.54 min
# Epoch: 014/100 | Batch 0000/0032 | Loss: 0.3983
# Epoch: 014/100 | Train: 94.70% | Validation: 63.51%
# Time elapsed: 10.27 min
# Epoch: 015/100 | Batch 0000/0032 | Loss: 0.2920
# Epoch: 015/100 | Train: 96.18% | Validation: 63.97%
# Time elapsed: 11.00 min
# Epoch: 016/100 | Batch 0000/0032 | Loss: 0.2373
# Epoch: 016/100 | Train: 97.05% | Validation: 62.36%
# Time elapsed: 11.73 min
# Epoch: 017/100 | Batch 0000/0032 | Loss: 0.2386
# Epoch: 017/100 | Train: 97.97% | Validation: 63.51%
# Time elapsed: 12.48 min
# Epoch: 018/100 | Batch 0000/0032 | Loss: 0.1381
# Epoch: 018/100 | Train: 98.74% | Validation: 63.74%
# Time elapsed: 13.21 min
# Epoch: 019/100 | Batch 0000/0032 | Loss: 0.1227
# Epoch: 019/100 | Train: 99.21% | Validation: 63.28%
# Time elapsed: 13.95 min
# Epoch: 020/100 | Batch 0000/0032 | Loss: 0.0744
# Epoch: 020/100 | Train: 99.28% | Validation: 63.97%
# Time elapsed: 14.69 min
# Epoch: 021/100 | Batch 0000/0032 | Loss: 0.0998
# Epoch: 021/100 | Train: 99.37% | Validation: 63.28%
# Time elapsed: 15.43 min
# Epoch: 022/100 | Batch 0000/0032 | Loss: 0.0808
# Epoch: 022/100 | Train: 99.45% | Validation: 63.05%
# Time elapsed: 16.18 min
# Epoch: 023/100 | Batch 0000/0032 | Loss: 0.0618
# Epoch: 023/100 | Train: 99.56% | Validation: 62.59%
# Time elapsed: 16.91 min
# Epoch: 024/100 | Batch 0000/0032 | Loss: 0.0560
# Epoch: 024/100 | Train: 99.58% | Validation: 63.28%
# Time elapsed: 17.77 min
# Epoch: 025/100 | Batch 0000/0032 | Loss: 0.0689
# Epoch: 025/100 | Train: 99.62% | Validation: 63.74%
# Time elapsed: 18.58 min
# Epoch: 026/100 | Batch 0000/0032 | Loss: 0.0603
# Epoch: 026/100 | Train: 99.62% | Validation: 63.74%
# Time elapsed: 19.34 min
# Epoch: 027/100 | Batch 0000/0032 | Loss: 0.0624
# Epoch: 027/100 | Train: 99.65% | Validation: 63.74%
# Time elapsed: 20.08 min
# Epoch: 028/100 | Batch 0000/0032 | Loss: 0.0499
# Epoch: 028/100 | Train: 99.65% | Validation: 63.74%
# Time elapsed: 20.84 min
# Epoch: 029/100 | Batch 0000/0032 | Loss: 0.0597
# Epoch: 029/100 | Train: 99.67% | Validation: 63.74%
# Time elapsed: 21.58 min
# Epoch: 030/100 | Batch 0000/0032 | Loss: 0.0527
# Epoch: 030/100 | Train: 99.69% | Validation: 63.74%
# Time elapsed: 22.33 min
# Epoch: 031/100 | Batch 0000/0032 | Loss: 0.0748
# Epoch: 031/100 | Train: 99.72% | Validation: 63.51%
# Time elapsed: 23.08 min
# Epoch: 032/100 | Batch 0000/0032 | Loss: 0.0352
# Epoch: 032/100 | Train: 99.72% | Validation: 63.51%
# Time elapsed: 23.81 min
# Epoch: 033/100 | Batch 0000/0032 | Loss: 0.0422
# Epoch: 033/100 | Train: 99.72% | Validation: 63.51%
# Time elapsed: 24.54 min
# Epoch: 034/100 | Batch 0000/0032 | Loss: 0.0582
# Epoch: 034/100 | Train: 99.72% | Validation: 63.51%
# Time elapsed: 25.27 min
# Epoch: 035/100 | Batch 0000/0032 | Loss: 0.0691
# Epoch: 035/100 | Train: 99.72% | Validation: 63.51%
# Time elapsed: 26.02 min
# Epoch: 036/100 | Batch 0000/0032 | Loss: 0.0396
# Epoch: 036/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 26.76 min
# Epoch: 037/100 | Batch 0000/0032 | Loss: 0.0551
# Epoch: 037/100 | Train: 99.73% | Validation: 63.74%
# Time elapsed: 27.51 min
# Epoch: 038/100 | Batch 0000/0032 | Loss: 0.0599
# Epoch: 038/100 | Train: 99.73% | Validation: 63.74%
# Time elapsed: 28.23 min
# Epoch: 039/100 | Batch 0000/0032 | Loss: 0.0516
# Epoch: 039/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 28.93 min
# Epoch: 040/100 | Batch 0000/0032 | Loss: 0.0612
# Epoch: 040/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 29.81 min
# Epoch: 041/100 | Batch 0000/0032 | Loss: 0.0463
# Epoch: 041/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 30.67 min
# Epoch: 042/100 | Batch 0000/0032 | Loss: 0.0421
# Epoch: 042/100 | Train: 99.73% | Validation: 63.74%
# Time elapsed: 31.48 min
# Epoch: 043/100 | Batch 0000/0032 | Loss: 0.0698
# Epoch: 043/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 32.22 min
# Epoch: 044/100 | Batch 0000/0032 | Loss: 0.0429
# Epoch: 044/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 32.95 min
# Epoch: 045/100 | Batch 0000/0032 | Loss: 0.0602
# Epoch: 045/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 33.68 min
# Epoch: 046/100 | Batch 0000/0032 | Loss: 0.0537
# Epoch: 046/100 | Train: 99.73% | Validation: 63.74%
# Time elapsed: 34.42 min
# Epoch: 047/100 | Batch 0000/0032 | Loss: 0.0504
# Epoch: 047/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 35.16 min
# Epoch: 048/100 | Batch 0000/0032 | Loss: 0.0429
# Epoch: 048/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 35.97 min
# Epoch: 049/100 | Batch 0000/0032 | Loss: 0.0571
# Epoch: 049/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 36.78 min
# Epoch: 050/100 | Batch 0000/0032 | Loss: 0.0580
# Epoch: 050/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 37.50 min
# Epoch: 051/100 | Batch 0000/0032 | Loss: 0.0416
# Epoch: 051/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 38.23 min
# Epoch: 052/100 | Batch 0000/0032 | Loss: 0.0531
# Epoch: 052/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 38.96 min
# Epoch: 053/100 | Batch 0000/0032 | Loss: 0.0561
# Epoch: 053/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 39.69 min
# Epoch: 054/100 | Batch 0000/0032 | Loss: 0.0673
# Epoch: 054/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 40.43 min
# Epoch: 055/100 | Batch 0000/0032 | Loss: 0.0557
# Epoch: 055/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 41.22 min
# Epoch: 056/100 | Batch 0000/0032 | Loss: 0.0459
# Epoch: 056/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 42.02 min
# Epoch: 057/100 | Batch 0000/0032 | Loss: 0.0560
# Epoch: 057/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 42.82 min
# Epoch: 058/100 | Batch 0000/0032 | Loss: 0.0434
# Epoch: 058/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 43.63 min
# Epoch: 059/100 | Batch 0000/0032 | Loss: 0.0516
# Epoch: 059/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 44.47 min
# Epoch: 060/100 | Batch 0000/0032 | Loss: 0.0658
# Epoch: 060/100 | Train: 99.74% | Validation: 63.74%
# Time elapsed: 45.33 min
# Epoch: 061/100 | Batch 0000/0032 | Loss: 0.0546
# Epoch: 061/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 46.17 min
# Epoch: 062/100 | Batch 0000/0032 | Loss: 0.0465
# Epoch: 062/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 47.01 min
# Epoch: 063/100 | Batch 0000/0032 | Loss: 0.0502
# Epoch: 063/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 47.82 min
# Epoch: 064/100 | Batch 0000/0032 | Loss: 0.0655
# Epoch: 064/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 48.64 min
# Epoch: 065/100 | Batch 0000/0032 | Loss: 0.0552
# Epoch: 065/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 49.52 min
# Epoch: 066/100 | Batch 0000/0032 | Loss: 0.0701
# Epoch: 066/100 | Train: 99.73% | Validation: 63.74%
# Time elapsed: 50.40 min
# Epoch: 067/100 | Batch 0000/0032 | Loss: 0.0490
# Epoch: 067/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 51.22 min
# Epoch: 068/100 | Batch 0000/0032 | Loss: 0.0618
# Epoch: 068/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 52.00 min
# Epoch: 069/100 | Batch 0000/0032 | Loss: 0.0403
# Epoch: 069/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 52.84 min
# Epoch: 070/100 | Batch 0000/0032 | Loss: 0.0619
# Epoch: 070/100 | Train: 99.73% | Validation: 63.74%
# Time elapsed: 53.64 min
# Epoch: 071/100 | Batch 0000/0032 | Loss: 0.0530
# Epoch: 071/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 54.43 min
# Epoch: 072/100 | Batch 0000/0032 | Loss: 0.0536
# Epoch: 072/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 55.19 min
# Epoch: 073/100 | Batch 0000/0032 | Loss: 0.0564
# Epoch: 073/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 55.94 min
# Epoch: 074/100 | Batch 0000/0032 | Loss: 0.0485
# Epoch: 074/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 56.70 min
# Epoch: 075/100 | Batch 0000/0032 | Loss: 0.0481
# Epoch: 075/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 57.46 min
# Epoch: 076/100 | Batch 0000/0032 | Loss: 0.0457
# Epoch: 076/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 58.25 min
# Epoch: 077/100 | Batch 0000/0032 | Loss: 0.0557
# Epoch: 077/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 59.06 min
# Epoch: 078/100 | Batch 0000/0032 | Loss: 0.0437
# Epoch: 078/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 59.82 min
# Epoch: 079/100 | Batch 0000/0032 | Loss: 0.0540
# Epoch: 079/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 60.59 min
# Epoch: 080/100 | Batch 0000/0032 | Loss: 0.0482
# Epoch: 080/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 61.37 min
# Epoch: 081/100 | Batch 0000/0032 | Loss: 0.0623
# Epoch: 081/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 62.23 min
# Epoch: 082/100 | Batch 0000/0032 | Loss: 0.0552
# Epoch: 082/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 63.06 min
# Epoch: 083/100 | Batch 0000/0032 | Loss: 0.0587
# Epoch: 083/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 63.90 min
# Epoch: 084/100 | Batch 0000/0032 | Loss: 0.0482
# Epoch: 084/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 64.70 min
# Epoch: 085/100 | Batch 0000/0032 | Loss: 0.0485
# Epoch: 085/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 65.40 min
# Epoch: 086/100 | Batch 0000/0032 | Loss: 0.0530
# Epoch: 086/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 66.17 min
# Epoch: 087/100 | Batch 0000/0032 | Loss: 0.0412
# Epoch: 087/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 67.05 min
# Epoch: 088/100 | Batch 0000/0032 | Loss: 0.0562
# Epoch: 088/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 67.76 min
# Epoch: 089/100 | Batch 0000/0032 | Loss: 0.0508
# Epoch: 089/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 68.44 min
# Epoch: 090/100 | Batch 0000/0032 | Loss: 0.0626
# Epoch: 090/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 69.12 min
# Epoch: 091/100 | Batch 0000/0032 | Loss: 0.0578
# Epoch: 091/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 69.81 min
# Epoch: 092/100 | Batch 0000/0032 | Loss: 0.0510
# Epoch: 092/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 70.49 min
# Epoch: 093/100 | Batch 0000/0032 | Loss: 0.0473
# Epoch: 093/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 71.16 min
# Epoch: 094/100 | Batch 0000/0032 | Loss: 0.0484
# Epoch: 094/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 71.83 min
# Epoch: 095/100 | Batch 0000/0032 | Loss: 0.0534
# Epoch: 095/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 72.52 min
# Epoch: 096/100 | Batch 0000/0032 | Loss: 0.0642
# Epoch: 096/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 73.18 min
# Epoch: 097/100 | Batch 0000/0032 | Loss: 0.0504
# Epoch: 097/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 73.87 min
# Epoch: 098/100 | Batch 0000/0032 | Loss: 0.0482
# Epoch: 098/100 | Train: 99.73% | Validation: 63.74%
# Time elapsed: 74.55 min
# Epoch: 099/100 | Batch 0000/0032 | Loss: 0.0670
# Epoch: 099/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 75.23 min
# Epoch: 100/100 | Batch 0000/0032 | Loss: 0.0670
# Epoch: 100/100 | Train: 99.72% | Validation: 63.74%
# Time elapsed: 75.95 min
# Total Training Time: 75.95 min
# Test accuracy 97.93%

# %%
from torchsummary import summary

summary(model, input_size=(3, 256, 256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 63, 63]          23,296
#               Tanh-2           [-1, 64, 63, 63]               0
#          MaxPool2d-3           [-1, 64, 31, 31]               0
#             Conv2d-4          [-1, 192, 31, 31]         307,392
#               Tanh-5          [-1, 192, 31, 31]               0
#          MaxPool2d-6          [-1, 192, 15, 15]               0
#             Linear-7                  [-1, 512]      22,118,912
#               Tanh-8                  [-1, 512]               0
#             Linear-9                  [-1, 101]          51,813
# ================================================================
# Total params: 22,501,413
# Trainable params: 22,501,413
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 7.50
# Params size (MB): 85.84
# Estimated Total Size (MB): 94.08
# ----------------------------------------------------------------

# %%
##########################
### SAVE MODEL
##########################
model.to(torch.device('cpu'))
os.makedirs('./models/cnn1-v2', exist_ok=True)
torch.save(model.state_dict(), './models/cnn1-v2/cnn1-v2.pt')
torch.save(optimizer.state_dict(), './models/cnn1-v2/cnn1-v2-optimizer.pt')
torch.save(scheduler.state_dict(), './models/cnn1-v2/cnn1-v2-scheduler.pt')
