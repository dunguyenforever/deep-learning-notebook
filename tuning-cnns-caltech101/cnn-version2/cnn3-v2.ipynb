# %%
import yaml
import argparse
import os
import sys
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Go up 1 directory level to import the helpers foldes
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# From local helper files
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helpers.helper_dataset import get_dataloaders_caltech101

# %%
##########################
### SETTINGS
##########################
parser = argparse.ArgumentParser()
script_dir = os.path.dirname(os.path.abspath('cnn1-v2.ipynb'))
default_yaml = os.path.join(script_dir, 'config-v2.yaml')
parser.add_argument('--settings_path',
                    type=str,
                    default=default_yaml,
                    help='Path to the YAML config file')

args, unknown = parser.parse_known_args() # Ignore unknown arguments

# Load YAML settings
with open(args.settings_path, 'r') as file:
    SETTINGS = yaml.load(file, Loader=yaml.FullLoader)

if torch.cuda.is_available():
    DEVICE = torch.device(f"cuda:{SETTINGS.get('cuda_device', 0)}")
else:
    DEVICE = torch.device('cpu')

# Set random seeds, etc.
set_all_seeds(SETTINGS['random_seed'])
# set_deterministic

# %%
##########################
### DATASET & DATALOADERS
##########################
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((256, 256)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((256, 256)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_loader, valid_loader, test_loader = get_dataloaders_caltech101(
    batch_size=SETTINGS['batch_size'],
    validation_fraction=SETTINGS['validation_percent'],
    train_transforms=train_transform,
    test_transforms=test_transform
)

##########################
### MODEL DEFINITION
##########################

class myCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # (1) 1st Convolutional Layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=11, stride=4, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride =2)
        )

        # (2) 2nd Convolutional Layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=5, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (3) 3rd Convolutional Layer
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=192, out_channels=384, kernel_size=3, padding=1),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (4) 4th Convolutional Layer
        self.conv4 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=1, stride=1)
        )

        # (4) Fully Connected Layers + Activation
        self.fc1 = nn.Sequential(
            nn.Linear(256 * 7 * 7, 512),
            nn.Tanh(),
            nn.Linear(512, num_classes)
        )

    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x


model = myCNN(num_classes=SETTINGS['num_classes'])
model.to(SETTINGS['cuda_device'])


##########################
### WEIGHT INITIALIZATION
##########################
def apply_weight_init(model, init_name='none'):
    """
    Apply weight initialization to Conv2d and Linear layers
    within an nn.Sequential model.
    """
    for layer in model.modules():
        if isinstance(layer, (nn.Conv2d, nn.Linear)):
            if init_name == 'xavier_uniform':
                nn.init.xavier_uniform_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'kaiming_normal':
                nn.init.kaiming_normal_(layer.weight, nonlinearity='relu')
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'orthogonal':
                nn.init.orthogonal_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            else:
                # If none or unknown, just leave PyTorch default
                pass

# Read weight init scheme from config
weight_init_config = SETTINGS.get('weight_init', {})
weight_init_name = weight_init_config.get('name', 'none')

apply_weight_init(model, init_name=weight_init_name)

##########################
### OPTIMIZER
##########################
optimizer_config = SETTINGS.get('optimizer', {})
optimizer_name = optimizer_config.get('name', 'Adam') # Default to Adam

weight_decay = float(optimizer_config.get('weight_decay', 0.0))
momentum = float(optimizer_config.get('momentum', 0.0)) # Default momentum for SGD
alpha = float(optimizer_config.get('alpha', 0.99)) # Default alpha for RMSprop

if optimizer_name == 'Adam':
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        weight_decay=weight_decay
    )
    
elif optimizer_name == 'SGD':
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay
    )

elif optimizer_name == 'RMSprop':
    optimizer = torch.optim.RMSProp(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay,
        alpha=alpha
    )

else:
    raise ValueError(f"Unknown optimizer: {optimizer_name}")

##########################
### LR SCHEDULER
##########################
scheduler_config = SETTINGS.get('scheduler', {})
scheduler_name = scheduler_config.get('name', 'None')

# Default to ReduceLROnPlateau, if not specified
if scheduler_name == 'ReduceLROnPlateau':
    factor = scheduler_config.get('factor', 0.1)
    mode = scheduler_config.get('mode', 'max')
    patience = scheduler_config.get('patience', 5)
    verbose = scheduler_config.get('verbose', True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        factor=factor,
        mode=mode,
        patience=patience
    )
elif scheduler_name == 'ExponentialLR':
    gamma = scheduler_config.get('gamma', 0.99)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name == 'StepLR':
    step_size = scheduler_config.get('step_size', 30)
    gamma = scheduler_config.get('gamma', 0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name.lower() == 'none':
    scheduler = None
else:
    raise ValueError(f"Unknown scheduler: {scheduler_name}")
# Out:
# Files already downloaded and verified

# %%
##########################
### TRAINING LOOP
##########################
# The helper_train.py presumably expects scheduler if not None,
# and you might specify how it’s applied (e.g., 'valid_acc').
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=SETTINGS['num_epochs'],
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=SETTINGS['cuda_device'],
    logging_interval=100,
    scheduler=scheduler,
    scheduler_on='valid_acc'  # or 'train_acc' or 'valid_loss'
)

##########################
### PLOTTING
##########################
plot_training_loss(
    minibatch_loss_list=minibatch_loss_list,
    num_epochs=SETTINGS['num_epochs'],
    iter_per_epoch=len(train_loader),
    results_dir=None,
    averaging_iterations=100
)
plt.show()

plot_accuracy(
    train_acc_list=train_acc_list,
    valid_acc_list=valid_acc_list,
    results_dir=None
)
plt.ylim([0, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0032 | Loss: 4.6317
# Epoch: 001/100 | Train: 22.07% | Validation: 26.56%
# Time elapsed: 0.69 min
# Epoch: 002/100 | Batch 0000/0032 | Loss: 3.8478
# Epoch: 002/100 | Train: 33.04% | Validation: 36.49%
# Time elapsed: 1.41 min
# Epoch: 003/100 | Batch 0000/0032 | Loss: 3.1163
# Epoch: 003/100 | Train: 40.31% | Validation: 42.03%
# Time elapsed: 2.11 min
# Epoch: 004/100 | Batch 0000/0032 | Loss: 2.8756
# Epoch: 004/100 | Train: 48.90% | Validation: 49.65%
# Time elapsed: 2.81 min
# Epoch: 005/100 | Batch 0000/0032 | Loss: 2.5542
# Epoch: 005/100 | Train: 54.85% | Validation: 54.73%
# Time elapsed: 3.50 min
# Epoch: 006/100 | Batch 0000/0032 | Loss: 2.0015
# Epoch: 006/100 | Train: 59.34% | Validation: 55.43%
# Time elapsed: 4.19 min
# Epoch: 007/100 | Batch 0000/0032 | Loss: 1.9473
# Epoch: 007/100 | Train: 64.66% | Validation: 57.27%
# Time elapsed: 4.87 min
# Epoch: 008/100 | Batch 0000/0032 | Loss: 1.4416
# Epoch: 008/100 | Train: 68.24% | Validation: 59.12%
# Time elapsed: 5.57 min
# Epoch: 009/100 | Batch 0000/0032 | Loss: 1.4786
# Epoch: 009/100 | Train: 72.00% | Validation: 60.97%
# Time elapsed: 6.27 min
# Epoch: 010/100 | Batch 0000/0032 | Loss: 1.0342
# Epoch: 010/100 | Train: 74.30% | Validation: 62.12%
# Time elapsed: 6.96 min
# Epoch: 011/100 | Batch 0000/0032 | Loss: 1.1100
# Epoch: 011/100 | Train: 77.40% | Validation: 64.43%
# Time elapsed: 7.65 min
# Epoch: 012/100 | Batch 0000/0032 | Loss: 0.9423
# Epoch: 012/100 | Train: 80.87% | Validation: 67.67%
# Time elapsed: 8.33 min
# Epoch: 013/100 | Batch 0000/0032 | Loss: 0.7322
# Epoch: 013/100 | Train: 82.93% | Validation: 65.13%
# Time elapsed: 9.01 min
# Epoch: 014/100 | Batch 0000/0032 | Loss: 0.6610
# Epoch: 014/100 | Train: 85.88% | Validation: 65.36%
# Time elapsed: 9.69 min
# Epoch: 015/100 | Batch 0000/0032 | Loss: 0.5454
# Epoch: 015/100 | Train: 87.77% | Validation: 65.59%
# Time elapsed: 10.38 min
# Epoch: 016/100 | Batch 0000/0032 | Loss: 0.5258
# Epoch: 016/100 | Train: 91.05% | Validation: 66.51%
# Time elapsed: 11.06 min
# Epoch: 017/100 | Batch 0000/0032 | Loss: 0.4584
# Epoch: 017/100 | Train: 93.08% | Validation: 68.59%
# Time elapsed: 11.74 min
# Epoch: 018/100 | Batch 0000/0032 | Loss: 0.3849
# Epoch: 018/100 | Train: 94.30% | Validation: 66.28%
# Time elapsed: 12.42 min
# Epoch: 019/100 | Batch 0000/0032 | Loss: 0.2929
# Epoch: 019/100 | Train: 96.03% | Validation: 67.67%
# Time elapsed: 13.10 min
# Epoch: 020/100 | Batch 0000/0032 | Loss: 0.3083
# Epoch: 020/100 | Train: 96.44% | Validation: 66.97%
# Time elapsed: 13.78 min
# Epoch: 021/100 | Batch 0000/0032 | Loss: 0.2153
# Epoch: 021/100 | Train: 97.69% | Validation: 66.97%
# Time elapsed: 14.46 min
# Epoch: 022/100 | Batch 0000/0032 | Loss: 0.1698
# Epoch: 022/100 | Train: 98.46% | Validation: 68.36%
# Time elapsed: 15.14 min
# Epoch: 023/100 | Batch 0000/0032 | Loss: 0.1145
# Epoch: 023/100 | Train: 99.06% | Validation: 67.44%
# Time elapsed: 15.83 min
# Epoch: 024/100 | Batch 0000/0032 | Loss: 0.1122
# Epoch: 024/100 | Train: 99.39% | Validation: 67.67%
# Time elapsed: 16.51 min
# Epoch: 025/100 | Batch 0000/0032 | Loss: 0.1035
# Epoch: 025/100 | Train: 99.55% | Validation: 67.44%
# Time elapsed: 17.19 min
# Epoch: 026/100 | Batch 0000/0032 | Loss: 0.0989
# Epoch: 026/100 | Train: 99.61% | Validation: 66.97%
# Time elapsed: 17.87 min
# Epoch: 027/100 | Batch 0000/0032 | Loss: 0.0673
# Epoch: 027/100 | Train: 99.57% | Validation: 67.44%
# Time elapsed: 18.55 min
# Epoch: 028/100 | Batch 0000/0032 | Loss: 0.0641
# Epoch: 028/100 | Train: 99.66% | Validation: 67.44%
# Time elapsed: 19.23 min
# Epoch: 029/100 | Batch 0000/0032 | Loss: 0.0692
# Epoch: 029/100 | Train: 99.68% | Validation: 67.67%
# Time elapsed: 19.92 min
# Epoch: 030/100 | Batch 0000/0032 | Loss: 0.0530
# Epoch: 030/100 | Train: 99.68% | Validation: 67.44%
# Time elapsed: 20.59 min
# Epoch: 031/100 | Batch 0000/0032 | Loss: 0.0711
# Epoch: 031/100 | Train: 99.71% | Validation: 66.97%
# Time elapsed: 21.23 min
# Epoch: 032/100 | Batch 0000/0032 | Loss: 0.0612
# Epoch: 032/100 | Train: 99.73% | Validation: 66.97%
# Time elapsed: 21.84 min
# Epoch: 033/100 | Batch 0000/0032 | Loss: 0.0642
# Epoch: 033/100 | Train: 99.73% | Validation: 66.97%
# Time elapsed: 22.47 min
# Epoch: 034/100 | Batch 0000/0032 | Loss: 0.0576
# Epoch: 034/100 | Train: 99.76% | Validation: 66.97%
# Time elapsed: 23.08 min
# Epoch: 035/100 | Batch 0000/0032 | Loss: 0.0627
# Epoch: 035/100 | Train: 99.78% | Validation: 66.97%
# Time elapsed: 23.82 min
# Epoch: 036/100 | Batch 0000/0032 | Loss: 0.0435
# Epoch: 036/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 24.56 min
# Epoch: 037/100 | Batch 0000/0032 | Loss: 0.0553
# Epoch: 037/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 25.30 min
# Epoch: 038/100 | Batch 0000/0032 | Loss: 0.0465
# Epoch: 038/100 | Train: 99.78% | Validation: 66.97%
# Time elapsed: 26.02 min
# Epoch: 039/100 | Batch 0000/0032 | Loss: 0.0505
# Epoch: 039/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 26.72 min
# Epoch: 040/100 | Batch 0000/0032 | Loss: 0.0514
# Epoch: 040/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 27.54 min
# Epoch: 041/100 | Batch 0000/0032 | Loss: 0.0475
# Epoch: 041/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 28.56 min
# Epoch: 042/100 | Batch 0000/0032 | Loss: 0.0449
# Epoch: 042/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 29.54 min
# Epoch: 043/100 | Batch 0000/0032 | Loss: 0.0598
# Epoch: 043/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 30.47 min
# Epoch: 044/100 | Batch 0000/0032 | Loss: 0.0538
# Epoch: 044/100 | Train: 99.78% | Validation: 66.97%
# Time elapsed: 31.16 min
# Epoch: 045/100 | Batch 0000/0032 | Loss: 0.0584
# Epoch: 045/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 31.86 min
# Epoch: 046/100 | Batch 0000/0032 | Loss: 0.0501
# Epoch: 046/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 32.56 min
# Epoch: 047/100 | Batch 0000/0032 | Loss: 0.0466
# Epoch: 047/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 33.26 min
# Epoch: 048/100 | Batch 0000/0032 | Loss: 0.0621
# Epoch: 048/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 33.94 min
# Epoch: 049/100 | Batch 0000/0032 | Loss: 0.0521
# Epoch: 049/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 34.63 min
# Epoch: 050/100 | Batch 0000/0032 | Loss: 0.0563
# Epoch: 050/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 35.35 min
# Epoch: 051/100 | Batch 0000/0032 | Loss: 0.0511
# Epoch: 051/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 36.05 min
# Epoch: 052/100 | Batch 0000/0032 | Loss: 0.0593
# Epoch: 052/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 36.74 min
# Epoch: 053/100 | Batch 0000/0032 | Loss: 0.0649
# Epoch: 053/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 37.43 min
# Epoch: 054/100 | Batch 0000/0032 | Loss: 0.0453
# Epoch: 054/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 38.12 min
# Epoch: 055/100 | Batch 0000/0032 | Loss: 0.0583
# Epoch: 055/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 38.80 min
# Epoch: 056/100 | Batch 0000/0032 | Loss: 0.0462
# Epoch: 056/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 39.49 min
# Epoch: 057/100 | Batch 0000/0032 | Loss: 0.0566
# Epoch: 057/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 40.19 min
# Epoch: 058/100 | Batch 0000/0032 | Loss: 0.0438
# Epoch: 058/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 40.88 min
# Epoch: 059/100 | Batch 0000/0032 | Loss: 0.0472
# Epoch: 059/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 41.57 min
# Epoch: 060/100 | Batch 0000/0032 | Loss: 0.0530
# Epoch: 060/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 42.25 min
# Epoch: 061/100 | Batch 0000/0032 | Loss: 0.0429
# Epoch: 061/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 42.95 min
# Epoch: 062/100 | Batch 0000/0032 | Loss: 0.0559
# Epoch: 062/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 43.64 min
# Epoch: 063/100 | Batch 0000/0032 | Loss: 0.0652
# Epoch: 063/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 44.37 min
# Epoch: 064/100 | Batch 0000/0032 | Loss: 0.0604
# Epoch: 064/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 45.06 min
# Epoch: 065/100 | Batch 0000/0032 | Loss: 0.0602
# Epoch: 065/100 | Train: 99.78% | Validation: 66.97%
# Time elapsed: 45.75 min
# Epoch: 066/100 | Batch 0000/0032 | Loss: 0.0500
# Epoch: 066/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 46.43 min
# Epoch: 067/100 | Batch 0000/0032 | Loss: 0.0482
# Epoch: 067/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 47.11 min
# Epoch: 068/100 | Batch 0000/0032 | Loss: 0.0468
# Epoch: 068/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 47.80 min
# Epoch: 069/100 | Batch 0000/0032 | Loss: 0.0529
# Epoch: 069/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 48.48 min
# Epoch: 070/100 | Batch 0000/0032 | Loss: 0.0534
# Epoch: 070/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 49.16 min
# Epoch: 071/100 | Batch 0000/0032 | Loss: 0.0500
# Epoch: 071/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 49.85 min
# Epoch: 072/100 | Batch 0000/0032 | Loss: 0.0624
# Epoch: 072/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 50.55 min
# Epoch: 073/100 | Batch 0000/0032 | Loss: 0.0602
# Epoch: 073/100 | Train: 99.78% | Validation: 66.97%
# Time elapsed: 51.23 min
# Epoch: 074/100 | Batch 0000/0032 | Loss: 0.0716
# Epoch: 074/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 51.91 min
# Epoch: 075/100 | Batch 0000/0032 | Loss: 0.0832
# Epoch: 075/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 52.59 min
# Epoch: 076/100 | Batch 0000/0032 | Loss: 0.0618
# Epoch: 076/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 53.32 min
# Epoch: 077/100 | Batch 0000/0032 | Loss: 0.0637
# Epoch: 077/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 54.00 min
# Epoch: 078/100 | Batch 0000/0032 | Loss: 0.0610
# Epoch: 078/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 54.73 min
# Epoch: 079/100 | Batch 0000/0032 | Loss: 0.0562
# Epoch: 079/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 55.41 min
# Epoch: 080/100 | Batch 0000/0032 | Loss: 0.0650
# Epoch: 080/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 56.10 min
# Epoch: 081/100 | Batch 0000/0032 | Loss: 0.0586
# Epoch: 081/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 56.79 min
# Epoch: 082/100 | Batch 0000/0032 | Loss: 0.0539
# Epoch: 082/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 57.48 min
# Epoch: 083/100 | Batch 0000/0032 | Loss: 0.0428
# Epoch: 083/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 58.17 min
# Epoch: 084/100 | Batch 0000/0032 | Loss: 0.0415
# Epoch: 084/100 | Train: 99.78% | Validation: 66.97%
# Time elapsed: 58.86 min
# Epoch: 085/100 | Batch 0000/0032 | Loss: 0.0404
# Epoch: 085/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 59.55 min
# Epoch: 086/100 | Batch 0000/0032 | Loss: 0.0515
# Epoch: 086/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 60.38 min
# Epoch: 087/100 | Batch 0000/0032 | Loss: 0.0575
# Epoch: 087/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 61.34 min
# Epoch: 088/100 | Batch 0000/0032 | Loss: 0.0454
# Epoch: 088/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 62.26 min
# Epoch: 089/100 | Batch 0000/0032 | Loss: 0.0614
# Epoch: 089/100 | Train: 99.78% | Validation: 66.97%
# Time elapsed: 63.11 min
# Epoch: 090/100 | Batch 0000/0032 | Loss: 0.0524
# Epoch: 090/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 63.87 min
# Epoch: 091/100 | Batch 0000/0032 | Loss: 0.0509
# Epoch: 091/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 64.62 min
# Epoch: 092/100 | Batch 0000/0032 | Loss: 0.0425
# Epoch: 092/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 65.42 min
# Epoch: 093/100 | Batch 0000/0032 | Loss: 0.0492
# Epoch: 093/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 66.20 min
# Epoch: 094/100 | Batch 0000/0032 | Loss: 0.0370
# Epoch: 094/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 66.98 min
# Epoch: 095/100 | Batch 0000/0032 | Loss: 0.0491
# Epoch: 095/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 67.71 min
# Epoch: 096/100 | Batch 0000/0032 | Loss: 0.0502
# Epoch: 096/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 68.45 min
# Epoch: 097/100 | Batch 0000/0032 | Loss: 0.0421
# Epoch: 097/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 69.21 min
# Epoch: 098/100 | Batch 0000/0032 | Loss: 0.0713
# Epoch: 098/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 69.94 min
# Epoch: 099/100 | Batch 0000/0032 | Loss: 0.0523
# Epoch: 099/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 70.67 min
# Epoch: 100/100 | Batch 0000/0032 | Loss: 0.0524
# Epoch: 100/100 | Train: 99.77% | Validation: 66.97%
# Time elapsed: 71.37 min
# Total Training Time: 71.37 min
# Test accuracy 98.13%

# %%
from torchsummary import summary
summary(model, input_size=(3, 256, 256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 63, 63]          23,296
#               Tanh-2           [-1, 64, 63, 63]               0
#          MaxPool2d-3           [-1, 64, 31, 31]               0
#             Conv2d-4          [-1, 192, 31, 31]         307,392
#               Tanh-5          [-1, 192, 31, 31]               0
#          MaxPool2d-6          [-1, 192, 15, 15]               0
#             Conv2d-7          [-1, 384, 15, 15]         663,936
#               Tanh-8          [-1, 384, 15, 15]               0
#          MaxPool2d-9            [-1, 384, 7, 7]               0
#            Conv2d-10            [-1, 256, 7, 7]         884,992
#              Tanh-11            [-1, 256, 7, 7]               0
#         MaxPool2d-12            [-1, 256, 7, 7]               0
#            Linear-13                  [-1, 512]       6,423,040
#              Tanh-14                  [-1, 512]               0
#            Linear-15                  [-1, 101]          51,813
# ================================================================
# Total params: 8,354,469
# Trainable params: 8,354,469
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 9.25
# Params size (MB): 31.87
# Estimated Total Size (MB): 41.87
# ----------------------------------------------------------------

# %%
##########################
### SAVE MODEL
##########################
model.to(torch.device('cpu'))
os.makedirs('./models/cnn3-v2', exist_ok=True)
torch.save(model.state_dict(), './models/cnn3-v2/cnn3-v2.pt')
torch.save(optimizer.state_dict(), './models/cnn3-v2/cnn3-v2-optimizer.pt')
torch.save(scheduler.state_dict(), './models/cnn3-v2/cnn3-v2-scheduler.pt')
