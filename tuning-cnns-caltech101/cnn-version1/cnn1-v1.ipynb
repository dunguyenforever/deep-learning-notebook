# %%
import yaml
import argparse
import os
import sys
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Go up 1 directory level to import the helpers foldes
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# From local helper files
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helpers.helper_dataset import get_dataloaders_caltech101

# %%
##########################
### SETTINGS
##########################
parser = argparse.ArgumentParser()
script_dir = os.path.dirname(os.path.abspath('cnn1-v1.ipynb'))
default_yaml = os.path.join(script_dir, 'config-v1.yaml')
parser.add_argument('--settings_path',
                    type=str,
                    default=default_yaml,
                    help='Path to the YAML config file')

args, unknown = parser.parse_known_args() # Ignore unknown arguments

# Load YAML settings
with open(args.settings_path, 'r') as file:
    SETTINGS = yaml.load(file, Loader=yaml.FullLoader)

if torch.cuda.is_available():
    DEVICE = torch.device(f"cuda:{SETTINGS.get('cuda_device', 0)}")
else:
    DEVICE = torch.device('cpu')

# Set random seeds, etc.
set_all_seeds(SETTINGS['random_seed'])
# set_deterministic

# %%
##########################
### DATASET & DATALOADERS
##########################
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.RandomRotation(30),
    torchvision.transforms.Resize((64, 64)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((256, 256)),
    torchvision.transforms.CenterCrop((64, 64)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_loader, valid_loader, test_loader = get_dataloaders_caltech101(
    batch_size=SETTINGS['batch_size'],
    validation_fraction=SETTINGS['validation_percent'],
    train_transforms=train_transform,
    test_transforms=test_transform
)

##########################
### MODEL DEFINITION
##########################

class myCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # (1) 1st Convolutional Layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=11, stride=4, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (2) 2nd Convolutional Layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=5, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (4) Fully Connected Layers + Activation
        self.fc1 = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Linear(192 * 3 * 3, 512),
            nn.Tanh(),
            nn.Dropout(p=0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x


model = myCNN(num_classes=SETTINGS['num_classes'])
model.to(SETTINGS['cuda_device'])


##########################
### WEIGHT INITIALIZATION
##########################
def apply_weight_init(model, init_name='none'):
    """
    Apply weight initialization to Conv2d and Linear layers
    within an nn.Sequential model.
    """
    for layer in model.modules():
        if isinstance(layer, (nn.Conv2d, nn.Linear)):
            if init_name == 'xavier_uniform':
                nn.init.xavier_uniform_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'kaiming_normal':
                nn.init.kaiming_normal_(layer.weight, nonlinearity='relu')
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'orthogonal':
                nn.init.orthogonal_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            else:
                # If none or unknown, just leave PyTorch default
                pass

# Read weight init scheme from config
weight_init_config = SETTINGS.get('weight_init', {})
weight_init_name = weight_init_config.get('name', 'none')

apply_weight_init(model, init_name=weight_init_name)

##########################
### OPTIMIZER
##########################
optimizer_config = SETTINGS.get('optimizer', {})
optimizer_name = optimizer_config.get('name', 'Adam') # Default to Adam

weight_decay = float(optimizer_config.get('weight_decay', 0.0))
momentum = float(optimizer_config.get('momentum', 0.0)) # Default momentum for SGD
alpha = float(optimizer_config.get('alpha', 0.99)) # Default alpha for RMSprop

if optimizer_name == 'Adam':
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        weight_decay=weight_decay
    )
    
elif optimizer_name == 'SGD':
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay
    )

elif optimizer_name == 'RMSprop':
    optimizer = torch.optim.RMSProp(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay,
        alpha=alpha
    )

else:
    raise ValueError(f"Unknown optimizer: {optimizer_name}")

##########################
### LR SCHEDULER
##########################
scheduler_config = SETTINGS.get('scheduler', {})
scheduler_name = scheduler_config.get('name', 'None')

# Default to ReduceLROnPlateau, if not specified
if scheduler_name == 'ReduceLROnPlateau':
    factor = scheduler_config.get('factor', 0.1)
    mode = scheduler_config.get('mode', 'max')
    patience = scheduler_config.get('patience', 5)
    verbose = scheduler_config.get('verbose', True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        factor=factor,
        mode=mode,
        patience=patience
    )
elif scheduler_name == 'ExponentialLR':
    gamma = scheduler_config.get('gamma', 0.99)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name == 'StepLR':
    step_size = scheduler_config.get('step_size', 30)
    gamma = scheduler_config.get('gamma', 0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name.lower() == 'none':
    scheduler = None
else:
    raise ValueError(f"Unknown scheduler: {scheduler_name}")
# Out:
# Files already downloaded and verified

# %%
##########################
### TRAINING LOOP
##########################
# The helper_train.py presumably expects scheduler if not None,
# and you might specify how it’s applied (e.g., 'valid_acc').
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=SETTINGS['num_epochs'],
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=SETTINGS['cuda_device'],
    logging_interval=100,
    scheduler=scheduler,
    scheduler_on='valid_acc'  # or 'train_acc' or 'valid_loss'
)

##########################
### PLOTTING
##########################
plot_training_loss(
    minibatch_loss_list=minibatch_loss_list,
    num_epochs=SETTINGS['num_epochs'],
    iter_per_epoch=len(train_loader),
    results_dir=None,
    averaging_iterations=100
)
plt.show()

plot_accuracy(
    train_acc_list=train_acc_list,
    valid_acc_list=valid_acc_list,
    results_dir=None
)
plt.ylim([0, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0032 | Loss: 4.7389
# Epoch: 001/100 | Train: 30.21% | Validation: 10.62%
# Time elapsed: 0.45 min
# Epoch: 002/100 | Batch 0000/0032 | Loss: 3.4593
# Epoch: 002/100 | Train: 38.27% | Validation: 9.70%
# Time elapsed: 0.89 min
# Epoch: 003/100 | Batch 0000/0032 | Loss: 2.9974
# Epoch: 003/100 | Train: 44.04% | Validation: 9.47%
# Time elapsed: 1.32 min
# Epoch: 004/100 | Batch 0000/0032 | Loss: 2.7782
# Epoch: 004/100 | Train: 47.50% | Validation: 9.47%
# Time elapsed: 1.67 min
# Epoch: 005/100 | Batch 0000/0032 | Loss: 2.7501
# Epoch: 005/100 | Train: 52.65% | Validation: 9.47%
# Time elapsed: 2.03 min
# Epoch: 006/100 | Batch 0000/0032 | Loss: 2.3033
# Epoch: 006/100 | Train: 54.77% | Validation: 12.93%
# Time elapsed: 2.39 min
# Epoch: 007/100 | Batch 0000/0032 | Loss: 2.0030
# Epoch: 007/100 | Train: 57.75% | Validation: 9.24%
# Time elapsed: 2.75 min
# Epoch: 008/100 | Batch 0000/0032 | Loss: 2.1848
# Epoch: 008/100 | Train: 58.76% | Validation: 11.78%
# Time elapsed: 3.12 min
# Epoch: 009/100 | Batch 0000/0032 | Loss: 2.1633
# Epoch: 009/100 | Train: 59.84% | Validation: 10.39%
# Time elapsed: 3.48 min
# Epoch: 010/100 | Batch 0000/0032 | Loss: 2.1631
# Epoch: 010/100 | Train: 62.78% | Validation: 9.93%
# Time elapsed: 3.85 min
# Epoch: 011/100 | Batch 0000/0032 | Loss: 1.8721
# Epoch: 011/100 | Train: 63.79% | Validation: 10.62%
# Time elapsed: 4.22 min
# Epoch: 012/100 | Batch 0000/0032 | Loss: 1.8776
# Epoch: 012/100 | Train: 63.77% | Validation: 8.08%
# Time elapsed: 4.59 min
# Epoch: 013/100 | Batch 0000/0032 | Loss: 1.8861
# Epoch: 013/100 | Train: 68.24% | Validation: 9.93%
# Time elapsed: 4.96 min
# Epoch: 014/100 | Batch 0000/0032 | Loss: 1.7482
# Epoch: 014/100 | Train: 69.14% | Validation: 9.01%
# Time elapsed: 5.33 min
# Epoch: 015/100 | Batch 0000/0032 | Loss: 1.5194
# Epoch: 015/100 | Train: 69.15% | Validation: 8.78%
# Time elapsed: 5.69 min
# Epoch: 016/100 | Batch 0000/0032 | Loss: 1.6211
# Epoch: 016/100 | Train: 69.63% | Validation: 9.24%
# Time elapsed: 6.06 min
# Epoch: 017/100 | Batch 0000/0032 | Loss: 1.5671
# Epoch: 017/100 | Train: 69.89% | Validation: 9.70%
# Time elapsed: 6.43 min
# Epoch: 018/100 | Batch 0000/0032 | Loss: 1.6530
# Epoch: 018/100 | Train: 70.59% | Validation: 9.47%
# Time elapsed: 6.79 min
# Epoch: 019/100 | Batch 0000/0032 | Loss: 1.4333
# Epoch: 019/100 | Train: 70.03% | Validation: 9.01%
# Time elapsed: 7.17 min
# Epoch: 020/100 | Batch 0000/0032 | Loss: 1.4841
# Epoch: 020/100 | Train: 69.85% | Validation: 9.47%
# Time elapsed: 7.54 min
# Epoch: 021/100 | Batch 0000/0032 | Loss: 1.5358
# Epoch: 021/100 | Train: 70.18% | Validation: 9.01%
# Time elapsed: 7.92 min
# Epoch: 022/100 | Batch 0000/0032 | Loss: 1.5246
# Epoch: 022/100 | Train: 70.35% | Validation: 9.24%
# Time elapsed: 8.28 min
# Epoch: 023/100 | Batch 0000/0032 | Loss: 1.4194
# Epoch: 023/100 | Train: 70.57% | Validation: 9.24%
# Time elapsed: 8.64 min
# Epoch: 024/100 | Batch 0000/0032 | Loss: 1.5230
# Epoch: 024/100 | Train: 70.21% | Validation: 9.01%
# Time elapsed: 9.01 min
# Epoch: 025/100 | Batch 0000/0032 | Loss: 1.7246
# Epoch: 025/100 | Train: 70.59% | Validation: 9.01%
# Time elapsed: 9.38 min
# Epoch: 026/100 | Batch 0000/0032 | Loss: 1.5037
# Epoch: 026/100 | Train: 70.36% | Validation: 9.01%
# Time elapsed: 9.74 min
# Epoch: 027/100 | Batch 0000/0032 | Loss: 1.5111
# Epoch: 027/100 | Train: 70.61% | Validation: 9.01%
# Time elapsed: 10.10 min
# Epoch: 028/100 | Batch 0000/0032 | Loss: 1.4992
# Epoch: 028/100 | Train: 70.21% | Validation: 9.01%
# Time elapsed: 10.47 min
# Epoch: 029/100 | Batch 0000/0032 | Loss: 1.4253
# Epoch: 029/100 | Train: 70.65% | Validation: 9.01%
# Time elapsed: 10.83 min
# Epoch: 030/100 | Batch 0000/0032 | Loss: 1.4547
# Epoch: 030/100 | Train: 70.36% | Validation: 9.01%
# Time elapsed: 11.20 min
# Epoch: 031/100 | Batch 0000/0032 | Loss: 1.3674
# Epoch: 031/100 | Train: 70.57% | Validation: 9.01%
# Time elapsed: 11.56 min
# Epoch: 032/100 | Batch 0000/0032 | Loss: 1.2656
# Epoch: 032/100 | Train: 70.42% | Validation: 9.01%
# Time elapsed: 11.93 min
# Epoch: 033/100 | Batch 0000/0032 | Loss: 1.3302
# Epoch: 033/100 | Train: 70.54% | Validation: 9.01%
# Time elapsed: 12.29 min
# Epoch: 034/100 | Batch 0000/0032 | Loss: 1.4383
# Epoch: 034/100 | Train: 70.47% | Validation: 9.01%
# Time elapsed: 12.67 min
# Epoch: 035/100 | Batch 0000/0032 | Loss: 1.3121
# Epoch: 035/100 | Train: 70.09% | Validation: 9.01%
# Time elapsed: 13.04 min
# Epoch: 036/100 | Batch 0000/0032 | Loss: 1.6099
# Epoch: 036/100 | Train: 70.23% | Validation: 9.01%
# Time elapsed: 13.41 min
# Epoch: 037/100 | Batch 0000/0032 | Loss: 1.4269
# Epoch: 037/100 | Train: 70.35% | Validation: 9.01%
# Time elapsed: 13.77 min
# Epoch: 038/100 | Batch 0000/0032 | Loss: 1.5652
# Epoch: 038/100 | Train: 70.14% | Validation: 9.01%
# Time elapsed: 14.14 min
# Epoch: 039/100 | Batch 0000/0032 | Loss: 1.4011
# Epoch: 039/100 | Train: 70.25% | Validation: 9.01%
# Time elapsed: 14.50 min
# Epoch: 040/100 | Batch 0000/0032 | Loss: 1.4772
# Epoch: 040/100 | Train: 70.42% | Validation: 9.01%
# Time elapsed: 14.87 min
# Epoch: 041/100 | Batch 0000/0032 | Loss: 1.4237
# Epoch: 041/100 | Train: 70.19% | Validation: 9.01%
# Time elapsed: 15.23 min
# Epoch: 042/100 | Batch 0000/0032 | Loss: 1.4483
# Epoch: 042/100 | Train: 70.46% | Validation: 9.01%
# Time elapsed: 15.60 min
# Epoch: 043/100 | Batch 0000/0032 | Loss: 1.4352
# Epoch: 043/100 | Train: 70.56% | Validation: 9.01%
# Time elapsed: 15.96 min
# Epoch: 044/100 | Batch 0000/0032 | Loss: 1.4143
# Epoch: 044/100 | Train: 69.79% | Validation: 9.01%
# Time elapsed: 16.33 min
# Epoch: 045/100 | Batch 0000/0032 | Loss: 1.4347
# Epoch: 045/100 | Train: 70.24% | Validation: 9.01%
# Time elapsed: 16.69 min
# Epoch: 046/100 | Batch 0000/0032 | Loss: 1.4079
# Epoch: 046/100 | Train: 70.68% | Validation: 9.01%
# Time elapsed: 17.06 min
# Epoch: 047/100 | Batch 0000/0032 | Loss: 1.3294
# Epoch: 047/100 | Train: 70.24% | Validation: 9.01%
# Time elapsed: 17.42 min
# Epoch: 048/100 | Batch 0000/0032 | Loss: 1.5922
# Epoch: 048/100 | Train: 70.28% | Validation: 9.01%
# Time elapsed: 17.79 min
# Epoch: 049/100 | Batch 0000/0032 | Loss: 1.5528
# Epoch: 049/100 | Train: 70.40% | Validation: 9.01%
# Time elapsed: 18.16 min
# Epoch: 050/100 | Batch 0000/0032 | Loss: 1.5090
# Epoch: 050/100 | Train: 70.61% | Validation: 9.01%
# Time elapsed: 18.52 min
# Epoch: 051/100 | Batch 0000/0032 | Loss: 1.4396
# Epoch: 051/100 | Train: 70.40% | Validation: 9.01%
# Time elapsed: 18.89 min
# Epoch: 052/100 | Batch 0000/0032 | Loss: 1.2836
# Epoch: 052/100 | Train: 70.08% | Validation: 9.01%
# Time elapsed: 19.25 min
# Epoch: 053/100 | Batch 0000/0032 | Loss: 1.5920
# Epoch: 053/100 | Train: 70.67% | Validation: 9.01%
# Time elapsed: 19.62 min
# Epoch: 054/100 | Batch 0000/0032 | Loss: 1.4165
# Epoch: 054/100 | Train: 70.45% | Validation: 9.01%
# Time elapsed: 19.98 min
# Epoch: 055/100 | Batch 0000/0032 | Loss: 1.5349
# Epoch: 055/100 | Train: 70.51% | Validation: 9.01%
# Time elapsed: 20.35 min
# Epoch: 056/100 | Batch 0000/0032 | Loss: 1.5230
# Epoch: 056/100 | Train: 70.41% | Validation: 9.01%
# Time elapsed: 20.71 min
# Epoch: 057/100 | Batch 0000/0032 | Loss: 1.4685
# Epoch: 057/100 | Train: 70.39% | Validation: 9.01%
# Time elapsed: 21.08 min
# Epoch: 058/100 | Batch 0000/0032 | Loss: 1.5130
# Epoch: 058/100 | Train: 70.45% | Validation: 9.01%
# Time elapsed: 21.44 min
# Epoch: 059/100 | Batch 0000/0032 | Loss: 1.3829
# Epoch: 059/100 | Train: 70.25% | Validation: 9.01%
# Time elapsed: 21.81 min
# Epoch: 060/100 | Batch 0000/0032 | Loss: 1.3654
# Epoch: 060/100 | Train: 70.62% | Validation: 9.01%
# Time elapsed: 22.20 min
# Epoch: 061/100 | Batch 0000/0032 | Loss: 1.4391
# Epoch: 061/100 | Train: 70.30% | Validation: 9.01%
# Time elapsed: 22.56 min
# Epoch: 062/100 | Batch 0000/0032 | Loss: 1.3277
# Epoch: 062/100 | Train: 70.31% | Validation: 9.01%
# Time elapsed: 22.92 min
# Epoch: 063/100 | Batch 0000/0032 | Loss: 1.5437
# Epoch: 063/100 | Train: 70.45% | Validation: 9.01%
# Time elapsed: 23.31 min
# Epoch: 064/100 | Batch 0000/0032 | Loss: 1.5330
# Epoch: 064/100 | Train: 70.04% | Validation: 9.01%
# Time elapsed: 23.71 min
# Epoch: 065/100 | Batch 0000/0032 | Loss: 1.5614
# Epoch: 065/100 | Train: 70.10% | Validation: 9.01%
# Time elapsed: 24.11 min
# Epoch: 066/100 | Batch 0000/0032 | Loss: 1.5267
# Epoch: 066/100 | Train: 70.98% | Validation: 9.01%
# Time elapsed: 24.53 min
# Epoch: 067/100 | Batch 0000/0032 | Loss: 1.4486
# Epoch: 067/100 | Train: 70.48% | Validation: 9.01%
# Time elapsed: 24.99 min
# Epoch: 068/100 | Batch 0000/0032 | Loss: 1.2781
# Epoch: 068/100 | Train: 70.35% | Validation: 9.01%
# Time elapsed: 25.42 min
# Epoch: 069/100 | Batch 0000/0032 | Loss: 1.4510
# Epoch: 069/100 | Train: 70.74% | Validation: 9.01%
# Time elapsed: 25.89 min
# Epoch: 070/100 | Batch 0000/0032 | Loss: 1.4921
# Epoch: 070/100 | Train: 70.18% | Validation: 9.01%
# Time elapsed: 26.36 min
# Epoch: 071/100 | Batch 0000/0032 | Loss: 1.3985
# Epoch: 071/100 | Train: 70.90% | Validation: 9.01%
# Time elapsed: 26.83 min
# Epoch: 072/100 | Batch 0000/0032 | Loss: 1.3484
# Epoch: 072/100 | Train: 70.68% | Validation: 9.01%
# Time elapsed: 27.29 min
# Epoch: 073/100 | Batch 0000/0032 | Loss: 1.4736
# Epoch: 073/100 | Train: 70.39% | Validation: 9.01%
# Time elapsed: 27.76 min
# Epoch: 074/100 | Batch 0000/0032 | Loss: 1.4394
# Epoch: 074/100 | Train: 70.31% | Validation: 9.01%
# Time elapsed: 28.28 min
# Epoch: 075/100 | Batch 0000/0032 | Loss: 1.6785
# Epoch: 075/100 | Train: 70.87% | Validation: 9.01%
# Time elapsed: 28.74 min
# Epoch: 076/100 | Batch 0000/0032 | Loss: 1.2589
# Epoch: 076/100 | Train: 70.01% | Validation: 9.01%
# Time elapsed: 29.21 min
# Epoch: 077/100 | Batch 0000/0032 | Loss: 1.3654
# Epoch: 077/100 | Train: 70.15% | Validation: 9.01%
# Time elapsed: 29.68 min
# Epoch: 078/100 | Batch 0000/0032 | Loss: 1.5584
# Epoch: 078/100 | Train: 70.01% | Validation: 9.01%
# Time elapsed: 30.15 min
# Epoch: 079/100 | Batch 0000/0032 | Loss: 1.4818
# Epoch: 079/100 | Train: 70.04% | Validation: 9.01%
# Time elapsed: 30.61 min
# Epoch: 080/100 | Batch 0000/0032 | Loss: 1.5795
# Epoch: 080/100 | Train: 70.26% | Validation: 9.01%
# Time elapsed: 31.09 min
# Epoch: 081/100 | Batch 0000/0032 | Loss: 1.4667
# Epoch: 081/100 | Train: 70.35% | Validation: 9.01%
# Time elapsed: 31.56 min
# Epoch: 082/100 | Batch 0000/0032 | Loss: 1.4711
# Epoch: 082/100 | Train: 70.07% | Validation: 9.01%
# Time elapsed: 32.03 min
# Epoch: 083/100 | Batch 0000/0032 | Loss: 1.4647
# Epoch: 083/100 | Train: 70.43% | Validation: 9.01%
# Time elapsed: 32.50 min
# Epoch: 084/100 | Batch 0000/0032 | Loss: 1.5178
# Epoch: 084/100 | Train: 70.14% | Validation: 9.01%
# Time elapsed: 32.96 min
# Epoch: 085/100 | Batch 0000/0032 | Loss: 1.5062
# Epoch: 085/100 | Train: 70.46% | Validation: 9.01%
# Time elapsed: 33.43 min
# Epoch: 086/100 | Batch 0000/0032 | Loss: 1.3882
# Epoch: 086/100 | Train: 70.57% | Validation: 9.01%
# Time elapsed: 33.90 min
# Epoch: 087/100 | Batch 0000/0032 | Loss: 1.4568
# Epoch: 087/100 | Train: 70.07% | Validation: 9.01%
# Time elapsed: 34.37 min
# Epoch: 088/100 | Batch 0000/0032 | Loss: 1.4125
# Epoch: 088/100 | Train: 70.07% | Validation: 9.01%
# Time elapsed: 34.84 min
# Epoch: 089/100 | Batch 0000/0032 | Loss: 1.2963
# Epoch: 089/100 | Train: 70.13% | Validation: 9.01%
# Time elapsed: 35.31 min
# Epoch: 090/100 | Batch 0000/0032 | Loss: 1.6357
# Epoch: 090/100 | Train: 70.76% | Validation: 9.01%
# Time elapsed: 35.78 min
# Epoch: 091/100 | Batch 0000/0032 | Loss: 1.3980
# Epoch: 091/100 | Train: 70.15% | Validation: 9.01%
# Time elapsed: 36.25 min
# Epoch: 092/100 | Batch 0000/0032 | Loss: 1.4602
# Epoch: 092/100 | Train: 70.68% | Validation: 9.01%
# Time elapsed: 36.70 min
# Epoch: 093/100 | Batch 0000/0032 | Loss: 1.3791
# Epoch: 093/100 | Train: 69.93% | Validation: 9.01%
# Time elapsed: 37.13 min
# Epoch: 094/100 | Batch 0000/0032 | Loss: 1.6069
# Epoch: 094/100 | Train: 70.58% | Validation: 9.01%
# Time elapsed: 37.60 min
# Epoch: 095/100 | Batch 0000/0032 | Loss: 1.4616
# Epoch: 095/100 | Train: 70.67% | Validation: 9.01%
# Time elapsed: 38.07 min
# Epoch: 096/100 | Batch 0000/0032 | Loss: 1.6028
# Epoch: 096/100 | Train: 70.51% | Validation: 9.01%
# Time elapsed: 38.55 min
# Epoch: 097/100 | Batch 0000/0032 | Loss: 1.2946
# Epoch: 097/100 | Train: 70.36% | Validation: 9.01%
# Time elapsed: 38.95 min
# Epoch: 098/100 | Batch 0000/0032 | Loss: 1.5838
# Epoch: 098/100 | Train: 70.95% | Validation: 9.01%
# Time elapsed: 39.36 min
# Epoch: 099/100 | Batch 0000/0032 | Loss: 1.4125
# Epoch: 099/100 | Train: 70.10% | Validation: 9.01%
# Time elapsed: 39.74 min
# Epoch: 100/100 | Batch 0000/0032 | Loss: 1.4526
# Epoch: 100/100 | Train: 70.03% | Validation: 9.01%
# Time elapsed: 40.11 min
# Total Training Time: 40.11 min
# Test accuracy 9.21%

# %%
from torchsummary import summary

summary(model, input_size=(3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 15, 15]          23,296
#               Tanh-2           [-1, 64, 15, 15]               0
#          MaxPool2d-3             [-1, 64, 7, 7]               0
#             Conv2d-4            [-1, 192, 7, 7]         307,392
#               Tanh-5            [-1, 192, 7, 7]               0
#          MaxPool2d-6            [-1, 192, 3, 3]               0
#            Dropout-7                 [-1, 1728]               0
#             Linear-8                  [-1, 512]         885,248
#               Tanh-9                  [-1, 512]               0
#           Dropout-10                  [-1, 512]               0
#            Linear-11                  [-1, 101]          51,813
# ================================================================
# Total params: 1,267,749
# Trainable params: 1,267,749
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.43
# Params size (MB): 4.84
# Estimated Total Size (MB): 5.31
# ----------------------------------------------------------------

# %%
##########################
### SAVE MODEL
##########################
model.to(torch.device('cpu'))
os.makedirs('./models/cnn1-v1', exist_ok=True)
torch.save(model.state_dict(), './models/cnn1-v1/cnn1-v1.pt')
torch.save(optimizer.state_dict(), './models/cnn1-v1/cnn1-v1-optimizer.pt')
torch.save(scheduler.state_dict(), './models/cnn1-v1/cnn1-v1-scheduler.pt')
