# %%
import yaml
import argparse
import os
import sys
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Go up 1 directory level to import the helpers foldes
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# From local helper files
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helpers.helper_dataset import get_dataloaders_caltech101

# %%
##########################
### SETTINGS
##########################
parser = argparse.ArgumentParser()
script_dir = os.path.dirname(os.path.abspath('cnn1-v3.ipynb'))
default_yaml = os.path.join(script_dir, 'config-v3.yaml')
parser.add_argument('--settings_path',
                    type=str,
                    default=default_yaml,
                    help='Path to the YAML config file')

args, unknown = parser.parse_known_args() # Ignore unknown arguments

# Load YAML settings
with open(args.settings_path, 'r') as file:
    SETTINGS = yaml.load(file, Loader=yaml.FullLoader)

if torch.cuda.is_available():
    DEVICE = torch.device(f"cuda:{SETTINGS.get('cuda_device', 0)}")
else:
    DEVICE = torch.device('cpu')

# Set random seeds, etc.
set_all_seeds(SETTINGS['random_seed'])
# set_deterministic

# %%
##########################
### DATASET & DATALOADERS
##########################
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((200, 200)),
    torchvision.transforms.RandomCrop((128, 128)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((200, 200)),
    torchvision.transforms.CenterCrop((128, 128)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_loader, valid_loader, test_loader = get_dataloaders_caltech101(
    batch_size=SETTINGS['batch_size'],
    validation_fraction=SETTINGS['validation_percent'],
    train_transforms=train_transform,
    test_transforms=test_transform
)

##########################
### MODEL DEFINITION
##########################

class myCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # (1) 1st Convolutional Layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=11, stride=4, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride =2)
        )

        # (2) 2nd Convolutional Layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=5, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (3) 3rd Convolutional Layer
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=192, out_channels=384, kernel_size=3, padding=1),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (4) 4th Convolutional Layer
        self.conv4 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=1, stride=1)
        )

        # (4) Fully Connected Layers + Activation
        self.fc1 = nn.Sequential(
            nn.Linear(256 * 3 * 3, 512),
            nn.Tanh(),
            nn.Linear(512, num_classes)
        )

    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x


model = myCNN(num_classes=SETTINGS['num_classes'])
model.to(SETTINGS['cuda_device'])


##########################
### WEIGHT INITIALIZATION
##########################
def apply_weight_init(model, init_name='none'):
    """
    Apply weight initialization to Conv2d and Linear layers
    within an nn.Sequential model.
    """
    for layer in model.modules():
        if isinstance(layer, (nn.Conv2d, nn.Linear)):
            if init_name == 'xavier_uniform':
                nn.init.xavier_uniform_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'kaiming_normal':
                nn.init.kaiming_normal_(layer.weight, nonlinearity='relu')
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'orthogonal':
                nn.init.orthogonal_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            else:
                # If none or unknown, just leave PyTorch default
                pass

# Read weight init scheme from config
weight_init_config = SETTINGS.get('weight_init', {})
weight_init_name = weight_init_config.get('name', 'none')

apply_weight_init(model, init_name=weight_init_name)

##########################
### OPTIMIZER
##########################
optimizer_config = SETTINGS.get('optimizer', {})
optimizer_name = optimizer_config.get('name', 'Adam') # Default to Adam

weight_decay = float(optimizer_config.get('weight_decay', 0.0))
momentum = float(optimizer_config.get('momentum', 0.0)) # Default momentum for SGD


if optimizer_name == 'Adam':
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        weight_decay=weight_decay
    )
    
elif optimizer_name == 'SGD':
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay
    )

elif optimizer_name == 'RMSprop':
    alpha = float(optimizer_config.get('alpha', 0.99)) # Default alpha for RMSprop
    eps = float(optimizer_config.get('eps', 1e-8))
    optimizer = torch.optim.RMSprop(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay,
        alpha=alpha
    )

else:
    raise ValueError(f"Unknown optimizer: {optimizer_name}")

##########################
### LR SCHEDULER
##########################
scheduler_config = SETTINGS.get('scheduler', {})
scheduler_name = scheduler_config.get('name', 'None')

# Default to ReduceLROnPlateau, if not specified
if scheduler_name == 'ReduceLROnPlateau':
    factor = scheduler_config.get('factor', 0.1)
    mode = scheduler_config.get('mode', 'max')
    patience = scheduler_config.get('patience', 5)
    verbose = scheduler_config.get('verbose', True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        factor=factor,
        mode=mode,
        patience=patience
    )
elif scheduler_name == 'ExponentialLR':
    gamma = scheduler_config.get('gamma', 0.99)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name == 'StepLR':
    step_size = scheduler_config.get('step_size', 30)
    gamma = scheduler_config.get('gamma', 0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name.lower() == 'none':
    scheduler = None
else:
    raise ValueError(f"Unknown scheduler: {scheduler_name}")
# Out:
# Files already downloaded and verified

# %%
##########################
### TRAINING LOOP
##########################
# The helper_train.py presumably expects scheduler if not None,
# and you might specify how it’s applied (e.g., 'valid_acc').
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=SETTINGS['num_epochs'],
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=SETTINGS['cuda_device'],
    logging_interval=100,
    scheduler=scheduler,
    scheduler_on='valid_acc'  # or 'train_acc' or 'valid_loss'
)

##########################
### PLOTTING
##########################
plot_training_loss(
    minibatch_loss_list=minibatch_loss_list,
    num_epochs=SETTINGS['num_epochs'],
    iter_per_epoch=len(train_loader),
    results_dir=None,
    averaging_iterations=100
)
plt.show()

plot_accuracy(
    train_acc_list=train_acc_list,
    valid_acc_list=valid_acc_list,
    results_dir=None
)
plt.ylim([0, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0032 | Loss: 4.6023
# Epoch: 001/100 | Train: 12.49% | Validation: 16.17%
# Time elapsed: 0.48 min
# Epoch: 002/100 | Batch 0000/0032 | Loss: 4.3560
# Epoch: 002/100 | Train: 11.16% | Validation: 12.01%
# Time elapsed: 0.94 min
# Epoch: 003/100 | Batch 0000/0032 | Loss: 4.1552
# Epoch: 003/100 | Train: 13.94% | Validation: 18.94%
# Time elapsed: 1.41 min
# Epoch: 004/100 | Batch 0000/0032 | Loss: 4.0756
# Epoch: 004/100 | Train: 17.02% | Validation: 21.71%
# Time elapsed: 1.89 min
# Epoch: 005/100 | Batch 0000/0032 | Loss: 3.9741
# Epoch: 005/100 | Train: 14.70% | Validation: 15.47%
# Time elapsed: 2.38 min
# Epoch: 006/100 | Batch 0000/0032 | Loss: 3.8742
# Epoch: 006/100 | Train: 19.58% | Validation: 23.33%
# Time elapsed: 2.86 min
# Epoch: 007/100 | Batch 0000/0032 | Loss: 3.9306
# Epoch: 007/100 | Train: 17.31% | Validation: 20.79%
# Time elapsed: 3.35 min
# Epoch: 008/100 | Batch 0000/0032 | Loss: 3.9295
# Epoch: 008/100 | Train: 21.58% | Validation: 25.40%
# Time elapsed: 3.84 min
# Epoch: 009/100 | Batch 0000/0032 | Loss: 3.9113
# Epoch: 009/100 | Train: 24.19% | Validation: 27.48%
# Time elapsed: 4.33 min
# Epoch: 010/100 | Batch 0000/0032 | Loss: 3.5854
# Epoch: 010/100 | Train: 22.45% | Validation: 24.71%
# Time elapsed: 4.81 min
# Epoch: 011/100 | Batch 0000/0032 | Loss: 3.7057
# Epoch: 011/100 | Train: 23.58% | Validation: 27.94%
# Time elapsed: 5.29 min
# Epoch: 012/100 | Batch 0000/0032 | Loss: 3.6288
# Epoch: 012/100 | Train: 25.54% | Validation: 29.33%
# Time elapsed: 5.78 min
# Epoch: 013/100 | Batch 0000/0032 | Loss: 3.4183
# Epoch: 013/100 | Train: 23.57% | Validation: 28.87%
# Epoch: 072/100 | Train: 62.28% | Validation: 55.89%
# Time elapsed: 34.09 min
# Epoch: 073/100 | Batch 0000/0032 | Loss: 1.4870
# Epoch: 073/100 | Train: 62.02% | Validation: 56.12%
# Time elapsed: 34.57 min
# Epoch: 074/100 | Batch 0000/0032 | Loss: 1.6534
# Epoch: 074/100 | Train: 62.66% | Validation: 55.66%
# Time elapsed: 35.05 min
# Epoch: 075/100 | Batch 0000/0032 | Loss: 1.7089
# Epoch: 075/100 | Train: 62.33% | Validation: 56.12%
# Time elapsed: 35.52 min
# Epoch: 076/100 | Batch 0000/0032 | Loss: 1.5120
# Epoch: 076/100 | Train: 62.34% | Validation: 55.89%
# Time elapsed: 35.99 min
# Epoch: 077/100 | Batch 0000/0032 | Loss: 1.4184
# Epoch: 077/100 | Train: 62.38% | Validation: 55.89%
# Time elapsed: 36.46 min
# Epoch: 078/100 | Batch 0000/0032 | Loss: 1.5643
# Epoch: 078/100 | Train: 62.02% | Validation: 55.89%
# Time elapsed: 36.93 min
# Epoch: 079/100 | Batch 0000/0032 | Loss: 1.4343
# Epoch: 079/100 | Train: 62.24% | Validation: 55.89%
# Time elapsed: 37.41 min
# Epoch: 080/100 | Batch 0000/0032 | Loss: 1.4419
# Epoch: 080/100 | Train: 62.43% | Validation: 55.89%
# Time elapsed: 37.88 min
# Epoch: 081/100 | Batch 0000/0032 | Loss: 1.3454
# Epoch: 081/100 | Train: 62.43% | Validation: 55.89%
# Time elapsed: 38.35 min
# Epoch: 082/100 | Batch 0000/0032 | Loss: 1.4347
# Epoch: 082/100 | Train: 62.52% | Validation: 55.89%
# Time elapsed: 38.83 min
# Epoch: 083/100 | Batch 0000/0032 | Loss: 1.4525
# Epoch: 083/100 | Train: 62.38% | Validation: 55.89%
# Time elapsed: 39.30 min
# Epoch: 084/100 | Batch 0000/0032 | Loss: 1.6684
# Epoch: 084/100 | Train: 62.67% | Validation: 55.89%
# Time elapsed: 39.77 min
# Epoch: 085/100 | Batch 0000/0032 | Loss: 1.5435
# Epoch: 085/100 | Train: 62.16% | Validation: 55.89%
# Time elapsed: 40.24 min
# Epoch: 086/100 | Batch 0000/0032 | Loss: 1.3933
# Epoch: 086/100 | Train: 62.35% | Validation: 55.89%
# Time elapsed: 40.71 min
# Epoch: 087/100 | Batch 0000/0032 | Loss: 1.4093
# Epoch: 087/100 | Train: 63.01% | Validation: 55.89%
# Time elapsed: 41.17 min
# Epoch: 088/100 | Batch 0000/0032 | Loss: 1.3719
# Epoch: 088/100 | Train: 62.32% | Validation: 55.89%
# Time elapsed: 41.64 min
# Epoch: 089/100 | Batch 0000/0032 | Loss: 1.5924
# Epoch: 089/100 | Train: 63.12% | Validation: 55.89%
# Time elapsed: 42.11 min
# Epoch: 090/100 | Batch 0000/0032 | Loss: 1.4998
# Epoch: 090/100 | Train: 61.87% | Validation: 55.89%
# Time elapsed: 42.58 min
# Epoch: 091/100 | Batch 0000/0032 | Loss: 1.6535
# Epoch: 091/100 | Train: 62.41% | Validation: 55.89%
# Time elapsed: 43.05 min
# Epoch: 092/100 | Batch 0000/0032 | Loss: 1.6441
# Epoch: 092/100 | Train: 62.39% | Validation: 55.89%
# Time elapsed: 43.51 min
# Epoch: 093/100 | Batch 0000/0032 | Loss: 1.4554
# Epoch: 093/100 | Train: 62.23% | Validation: 55.89%
# Time elapsed: 43.98 min
# Epoch: 094/100 | Batch 0000/0032 | Loss: 1.5115
# Epoch: 094/100 | Train: 62.73% | Validation: 55.89%
# Time elapsed: 44.45 min
# Epoch: 095/100 | Batch 0000/0032 | Loss: 1.5051
# Epoch: 095/100 | Train: 62.21% | Validation: 55.89%
# Time elapsed: 44.92 min
# Epoch: 096/100 | Batch 0000/0032 | Loss: 1.6122
# Epoch: 096/100 | Train: 61.95% | Validation: 55.89%
# Time elapsed: 45.39 min
# Epoch: 097/100 | Batch 0000/0032 | Loss: 1.6577
# Epoch: 097/100 | Train: 62.49% | Validation: 55.89%
# Time elapsed: 45.86 min
# Epoch: 098/100 | Batch 0000/0032 | Loss: 1.5378
# Epoch: 098/100 | Train: 62.39% | Validation: 55.89%
# Time elapsed: 46.33 min
# Epoch: 099/100 | Batch 0000/0032 | Loss: 1.6351
# Epoch: 099/100 | Train: 62.27% | Validation: 55.89%
# Time elapsed: 46.80 min
# Epoch: 100/100 | Batch 0000/0032 | Loss: 1.5867
# Epoch: 100/100 | Train: 62.24% | Validation: 55.89%
# Time elapsed: 47.27 min
# Total Training Time: 47.27 min
# Test accuracy 69.49%

# %%
from torchsummary import summary
summary(model, input_size=(3, 128, 128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 31, 31]          23,296
#               Tanh-2           [-1, 64, 31, 31]               0
#          MaxPool2d-3           [-1, 64, 15, 15]               0
#             Conv2d-4          [-1, 192, 15, 15]         307,392
#               Tanh-5          [-1, 192, 15, 15]               0
#          MaxPool2d-6            [-1, 192, 7, 7]               0
#             Conv2d-7            [-1, 384, 7, 7]         663,936
#               Tanh-8            [-1, 384, 7, 7]               0
#          MaxPool2d-9            [-1, 384, 3, 3]               0
#            Conv2d-10            [-1, 256, 3, 3]         884,992
#              Tanh-11            [-1, 256, 3, 3]               0
#         MaxPool2d-12            [-1, 256, 3, 3]               0
#            Linear-13                  [-1, 512]       1,180,160
#              Tanh-14                  [-1, 512]               0
#            Linear-15                  [-1, 101]          51,813
# ================================================================
# Total params: 3,111,589
# Trainable params: 3,111,589
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 2.15
# Params size (MB): 11.87
# Estimated Total Size (MB): 14.21
# ----------------------------------------------------------------

# %%
##########################
### SAVE MODEL
##########################
model.to(torch.device('cpu'))
os.makedirs('./models/cnn3-v3', exist_ok=True)
torch.save(model.state_dict(), './models/cnn3-v3/cnn3-v3.pt')
torch.save(optimizer.state_dict(), './models/cnn3-v3/cnn3-v3-optimizer.pt')
torch.save(scheduler.state_dict(), './models/cnn3-v3/cnn3-v3-scheduler.pt')
