# %%
import yaml
import argparse
import os
import sys
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Go up 1 directory level to import the helpers foldes
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# From local helper files
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helpers.helper_dataset import get_dataloaders_caltech101

# %%
##########################
### SETTINGS
##########################
parser = argparse.ArgumentParser()
script_dir = os.path.dirname(os.path.abspath('cnn1-v3.ipynb'))
default_yaml = os.path.join(script_dir, 'config-v3.yaml')
parser.add_argument('--settings_path',
                    type=str,
                    default=default_yaml,
                    help='Path to the YAML config file')

args, unknown = parser.parse_known_args() # Ignore unknown arguments

# Load YAML settings
with open(args.settings_path, 'r') as file:
    SETTINGS = yaml.load(file, Loader=yaml.FullLoader)

if torch.cuda.is_available():
    DEVICE = torch.device(f"cuda:{SETTINGS.get('cuda_device', 0)}")
else:
    DEVICE = torch.device('cpu')

# Set random seeds, etc.
set_all_seeds(SETTINGS['random_seed'])
# set_deterministic

# %%
##########################
### DATASET & DATALOADERS
##########################
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((200, 200)),
    torchvision.transforms.RandomCrop((128, 128)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Lambda(lambda image: image.convert('RGB')),
    torchvision.transforms.Resize((200, 200)),
    torchvision.transforms.CenterCrop((128, 128)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_loader, valid_loader, test_loader = get_dataloaders_caltech101(
    batch_size=SETTINGS['batch_size'],
    validation_fraction=SETTINGS['validation_percent'],
    train_transforms=train_transform,
    test_transforms=test_transform
)

##########################
### MODEL DEFINITION
##########################

class myCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # (1) 1st Convolutional Layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=11, stride=4, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride =2)
        )

        # (2) 2nd Convolutional Layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=5, padding=2),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        # (4) Fully Connected Layers + Activation
        self.fc1 = nn.Sequential(
            nn.Linear(192 * 7 * 7, 512),
            nn.Tanh(),
            nn.Linear(512, num_classes)
        )

    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x


model = myCNN(num_classes=SETTINGS['num_classes'])
model.to(SETTINGS['cuda_device'])


##########################
### WEIGHT INITIALIZATION
##########################
def apply_weight_init(model, init_name='none'):
    """
    Apply weight initialization to Conv2d and Linear layers
    within an nn.Sequential model.
    """
    for layer in model.modules():
        if isinstance(layer, (nn.Conv2d, nn.Linear)):
            if init_name == 'xavier_uniform':
                nn.init.xavier_uniform_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'kaiming_normal':
                nn.init.kaiming_normal_(layer.weight, nonlinearity='relu')
                nn.init.constant_(layer.bias, 0.0)
            elif init_name == 'orthogonal':
                nn.init.orthogonal_(layer.weight)
                nn.init.constant_(layer.bias, 0.0)
            else:
                # If none or unknown, just leave PyTorch default
                pass

# Read weight init scheme from config
weight_init_config = SETTINGS.get('weight_init', {})
weight_init_name = weight_init_config.get('name', 'none')

apply_weight_init(model, init_name=weight_init_name)

##########################
### OPTIMIZER
##########################
optimizer_config = SETTINGS.get('optimizer', {})
optimizer_name = optimizer_config.get('name', 'Adam') # Default to Adam

weight_decay = float(optimizer_config.get('weight_decay', 0.0))
momentum = float(optimizer_config.get('momentum', 0.0)) # Default momentum for SGD


if optimizer_name == 'Adam':
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        weight_decay=weight_decay
    )
    
elif optimizer_name == 'SGD':
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay
    )

elif optimizer_name == 'RMSprop':
    alpha = float(optimizer_config.get('alpha', 0.99))
    eps = float(optimizer_config.get('eps', 1e-8))
    optimizer = torch.optim.RMSprop(
        model.parameters(),
        lr=SETTINGS['learning_rate'],
        momentum=momentum,
        weight_decay=weight_decay,
        alpha=alpha
    )

else:
    raise ValueError(f"Unknown optimizer: {optimizer_name}")

##########################
### LR SCHEDULER
##########################
scheduler_config = SETTINGS.get('scheduler', {})
scheduler_name = scheduler_config.get('name', 'None')

# Default to ReduceLROnPlateau, if not specified
if scheduler_name == 'ReduceLROnPlateau':
    factor = scheduler_config.get('factor', 0.1)
    mode = scheduler_config.get('mode', 'max')
    patience = scheduler_config.get('patience', 5)
    verbose = scheduler_config.get('verbose', True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        factor=factor,
        mode=mode,
        patience=patience
    )
elif scheduler_name == 'ExponentialLR':
    gamma = scheduler_config.get('gamma', 0.99)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name == 'StepLR':
    step_size = scheduler_config.get('step_size', 30)
    gamma = scheduler_config.get('gamma', 0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name.lower() == 'none':
    scheduler = None
else:
    raise ValueError(f"Unknown scheduler: {scheduler_name}")
# Out:
# Files already downloaded and verified

# %%
##########################
### TRAINING LOOP
##########################
# The helper_train.py presumably expects scheduler if not None,
# and you might specify how it’s applied (e.g., 'valid_acc').
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=SETTINGS['num_epochs'],
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=SETTINGS['cuda_device'],
    logging_interval=100,
    scheduler=scheduler,
    scheduler_on='valid_acc'  # or 'train_acc' or 'valid_loss'
)

##########################
### PLOTTING
##########################
plot_training_loss(
    minibatch_loss_list=minibatch_loss_list,
    num_epochs=SETTINGS['num_epochs'],
    iter_per_epoch=len(train_loader),
    results_dir=None,
    averaging_iterations=100
)
plt.show()

plot_accuracy(
    train_acc_list=train_acc_list,
    valid_acc_list=valid_acc_list,
    results_dir=None
)
plt.ylim([0, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0032 | Loss: 4.6650
# Epoch: 001/100 | Train: 18.46% | Validation: 21.71%
# Time elapsed: 0.74 min
# Epoch: 002/100 | Batch 0000/0032 | Loss: 3.9107
# Epoch: 002/100 | Train: 21.85% | Validation: 27.02%
# Time elapsed: 1.46 min
# Epoch: 003/100 | Batch 0000/0032 | Loss: 3.7928
# Epoch: 003/100 | Train: 23.33% | Validation: 26.56%
# Time elapsed: 2.18 min
# Epoch: 004/100 | Batch 0000/0032 | Loss: 3.7563
# Epoch: 004/100 | Train: 24.78% | Validation: 29.10%
# Time elapsed: 2.81 min
# Epoch: 005/100 | Batch 0000/0032 | Loss: 3.6689
# Epoch: 005/100 | Train: 25.65% | Validation: 30.48%
# Time elapsed: 3.45 min
# Epoch: 006/100 | Batch 0000/0032 | Loss: 3.6996
# Epoch: 006/100 | Train: 27.67% | Validation: 30.95%
# Time elapsed: 4.09 min
# Epoch: 007/100 | Batch 0000/0032 | Loss: 3.3910
# Epoch: 007/100 | Train: 27.56% | Validation: 31.41%
# Time elapsed: 4.74 min
# Epoch: 008/100 | Batch 0000/0032 | Loss: 3.5445
# Epoch: 008/100 | Train: 27.40% | Validation: 31.64%
# Time elapsed: 5.31 min
# Epoch: 009/100 | Batch 0000/0032 | Loss: 3.4303
# Epoch: 009/100 | Train: 30.02% | Validation: 32.56%
# Time elapsed: 5.88 min
# Epoch: 010/100 | Batch 0000/0032 | Loss: 3.3196
# Epoch: 010/100 | Train: 31.25% | Validation: 35.80%
# Time elapsed: 6.50 min
# Epoch: 011/100 | Batch 0000/0032 | Loss: 3.1000
# Epoch: 011/100 | Train: 30.93% | Validation: 35.57%
# Time elapsed: 7.11 min
# Epoch: 012/100 | Batch 0000/0032 | Loss: 3.0857
# Epoch: 012/100 | Train: 33.25% | Validation: 36.72%
# Time elapsed: 7.71 min
# Epoch: 013/100 | Batch 0000/0032 | Loss: 3.0743
# Epoch: 013/100 | Train: 33.23% | Validation: 38.57%
# Time elapsed: 8.33 min
# Epoch: 014/100 | Batch 0000/0032 | Loss: 3.1125
# Epoch: 014/100 | Train: 34.91% | Validation: 40.42%
# Time elapsed: 8.92 min
# Epoch: 015/100 | Batch 0000/0032 | Loss: 2.8627
# Epoch: 015/100 | Train: 34.95% | Validation: 41.11%
# Time elapsed: 9.52 min
# Epoch: 016/100 | Batch 0000/0032 | Loss: 2.8925
# Epoch: 016/100 | Train: 35.66% | Validation: 42.73%
# Time elapsed: 10.12 min
# Epoch: 017/100 | Batch 0000/0032 | Loss: 3.0631
# Epoch: 017/100 | Train: 37.35% | Validation: 44.80%
# Time elapsed: 10.73 min
# Epoch: 018/100 | Batch 0000/0032 | Loss: 2.6564
# Epoch: 018/100 | Train: 36.04% | Validation: 40.65%
# Time elapsed: 11.34 min
# Epoch: 019/100 | Batch 0000/0032 | Loss: 2.8501
# Epoch: 019/100 | Train: 37.65% | Validation: 43.19%
# Time elapsed: 11.94 min
# Epoch: 020/100 | Batch 0000/0032 | Loss: 2.9538
# Epoch: 020/100 | Train: 37.81% | Validation: 42.73%
# Time elapsed: 12.54 min
# Epoch: 021/100 | Batch 0000/0032 | Loss: 2.8010
# Epoch: 021/100 | Train: 38.57% | Validation: 43.19%
# Time elapsed: 13.15 min
# Epoch: 022/100 | Batch 0000/0032 | Loss: 2.8191
# Epoch: 022/100 | Train: 40.39% | Validation: 47.11%
# Time elapsed: 13.75 min
# Epoch: 023/100 | Batch 0000/0032 | Loss: 2.7813
# Epoch: 023/100 | Train: 40.91% | Validation: 46.88%
# Time elapsed: 14.40 min
# Epoch: 024/100 | Batch 0000/0032 | Loss: 2.4848
# Epoch: 024/100 | Train: 42.18% | Validation: 44.11%
# Time elapsed: 15.01 min
# Epoch: 025/100 | Batch 0000/0032 | Loss: 2.4453
# Epoch: 025/100 | Train: 42.03% | Validation: 44.80%
# Time elapsed: 15.63 min
# Epoch: 026/100 | Batch 0000/0032 | Loss: 2.7738
# Epoch: 026/100 | Train: 40.76% | Validation: 43.88%
# Time elapsed: 16.24 min
# Epoch: 027/100 | Batch 0000/0032 | Loss: 2.6451
# Epoch: 027/100 | Train: 43.93% | Validation: 48.50%
# Time elapsed: 16.85 min
# Epoch: 028/100 | Batch 0000/0032 | Loss: 2.5096
# Epoch: 028/100 | Train: 42.66% | Validation: 47.11%
# Time elapsed: 17.48 min
# Epoch: 029/100 | Batch 0000/0032 | Loss: 2.4377
# Epoch: 029/100 | Train: 40.04% | Validation: 46.19%
# Time elapsed: 18.10 min
# Epoch: 030/100 | Batch 0000/0032 | Loss: 2.6746
# Epoch: 030/100 | Train: 43.90% | Validation: 49.42%
# Time elapsed: 18.69 min
# Epoch: 031/100 | Batch 0000/0032 | Loss: 2.5363
# Epoch: 031/100 | Train: 44.73% | Validation: 49.19%
# Time elapsed: 19.29 min
# Epoch: 032/100 | Batch 0000/0032 | Loss: 2.3718
# Epoch: 032/100 | Train: 43.79% | Validation: 47.34%
# Time elapsed: 19.90 min
# Epoch: 033/100 | Batch 0000/0032 | Loss: 2.3518
# Epoch: 033/100 | Train: 45.95% | Validation: 50.35%
# Time elapsed: 20.51 min
# Epoch: 034/100 | Batch 0000/0032 | Loss: 2.3758
# Epoch: 034/100 | Train: 46.22% | Validation: 49.19%
# Time elapsed: 21.09 min
# Epoch: 035/100 | Batch 0000/0032 | Loss: 1.9629
# Epoch: 035/100 | Train: 45.42% | Validation: 51.73%
# Time elapsed: 21.68 min
# Epoch: 036/100 | Batch 0000/0032 | Loss: 2.3228
# Epoch: 036/100 | Train: 46.07% | Validation: 51.27%
# Time elapsed: 22.27 min
# Epoch: 037/100 | Batch 0000/0032 | Loss: 2.1956
# Epoch: 037/100 | Train: 46.79% | Validation: 49.42%
# Time elapsed: 22.86 min
# Epoch: 038/100 | Batch 0000/0032 | Loss: 2.4733
# Epoch: 038/100 | Train: 47.12% | Validation: 49.19%
# Time elapsed: 23.45 min
# Epoch: 039/100 | Batch 0000/0032 | Loss: 2.1606
# Epoch: 039/100 | Train: 48.25% | Validation: 51.27%
# Time elapsed: 24.05 min
# Epoch: 040/100 | Batch 0000/0032 | Loss: 2.1188
# Epoch: 040/100 | Train: 48.63% | Validation: 49.42%
# Time elapsed: 24.63 min
# Epoch: 041/100 | Batch 0000/0032 | Loss: 2.2556
# Epoch: 041/100 | Train: 49.77% | Validation: 48.96%
# Time elapsed: 25.22 min
# Epoch: 042/100 | Batch 0000/0032 | Loss: 2.0408
# Epoch: 042/100 | Train: 50.87% | Validation: 51.27%
# Time elapsed: 25.80 min
# Epoch: 043/100 | Batch 0000/0032 | Loss: 2.2696
# Epoch: 043/100 | Train: 51.76% | Validation: 51.50%
# Time elapsed: 26.45 min
# Epoch: 044/100 | Batch 0000/0032 | Loss: 2.0101
# Epoch: 044/100 | Train: 51.83% | Validation: 53.58%
# Time elapsed: 27.18 min
# Epoch: 045/100 | Batch 0000/0032 | Loss: 1.9008
# Epoch: 045/100 | Train: 52.99% | Validation: 52.19%
# Time elapsed: 27.86 min
# Epoch: 046/100 | Batch 0000/0032 | Loss: 2.0845
# Epoch: 046/100 | Train: 52.62% | Validation: 53.81%
# Time elapsed: 28.50 min
# Epoch: 047/100 | Batch 0000/0032 | Loss: 1.8588
# Epoch: 047/100 | Train: 52.88% | Validation: 53.58%
# Time elapsed: 29.09 min
# Epoch: 048/100 | Batch 0000/0032 | Loss: 2.1484
# Epoch: 048/100 | Train: 53.42% | Validation: 53.35%
# Time elapsed: 29.69 min
# Epoch: 049/100 | Batch 0000/0032 | Loss: 1.7408
# Epoch: 049/100 | Train: 53.05% | Validation: 51.96%
# Time elapsed: 30.31 min
# Epoch: 050/100 | Batch 0000/0032 | Loss: 1.9926
# Epoch: 050/100 | Train: 53.39% | Validation: 53.58%
# Time elapsed: 30.91 min
# Epoch: 051/100 | Batch 0000/0032 | Loss: 1.9562
# Epoch: 051/100 | Train: 53.89% | Validation: 53.81%
# Time elapsed: 31.51 min
# Epoch: 052/100 | Batch 0000/0032 | Loss: 2.1500
# Epoch: 052/100 | Train: 54.13% | Validation: 52.66%
# Time elapsed: 32.10 min
# Epoch: 053/100 | Batch 0000/0032 | Loss: 1.7810
# Epoch: 053/100 | Train: 53.70% | Validation: 52.42%
# Time elapsed: 32.69 min
# Epoch: 054/100 | Batch 0000/0032 | Loss: 1.7063
# Epoch: 054/100 | Train: 53.70% | Validation: 53.58%
# Time elapsed: 33.28 min
# Epoch: 055/100 | Batch 0000/0032 | Loss: 1.8535
# Epoch: 055/100 | Train: 54.09% | Validation: 52.89%
# Time elapsed: 33.86 min
# Epoch: 056/100 | Batch 0000/0032 | Loss: 1.9168
# Epoch: 056/100 | Train: 54.57% | Validation: 53.12%
# Time elapsed: 34.45 min
# Epoch: 057/100 | Batch 0000/0032 | Loss: 1.7553
# Epoch: 057/100 | Train: 54.28% | Validation: 53.35%
# Time elapsed: 35.04 min
# Epoch: 058/100 | Batch 0000/0032 | Loss: 1.9081
# Epoch: 058/100 | Train: 54.16% | Validation: 52.89%
# Time elapsed: 35.63 min
# Epoch: 059/100 | Batch 0000/0032 | Loss: 1.8663
# Epoch: 059/100 | Train: 54.80% | Validation: 52.89%
# Time elapsed: 36.23 min
# Epoch: 060/100 | Batch 0000/0032 | Loss: 1.9717
# Epoch: 060/100 | Train: 54.21% | Validation: 52.89%
# Time elapsed: 36.81 min
# Epoch: 061/100 | Batch 0000/0032 | Loss: 1.9478
# Epoch: 061/100 | Train: 54.04% | Validation: 52.89%
# Time elapsed: 37.40 min
# Epoch: 062/100 | Batch 0000/0032 | Loss: 1.8036
# Epoch: 062/100 | Train: 53.88% | Validation: 52.89%
# Time elapsed: 38.21 min
# Epoch: 063/100 | Batch 0000/0032 | Loss: 1.7861
# Epoch: 063/100 | Train: 54.24% | Validation: 52.89%
# Time elapsed: 38.86 min
# Epoch: 064/100 | Batch 0000/0032 | Loss: 1.8404
# Epoch: 064/100 | Train: 53.89% | Validation: 53.12%
# Time elapsed: 39.53 min
# Epoch: 065/100 | Batch 0000/0032 | Loss: 1.8716
# Epoch: 065/100 | Train: 53.64% | Validation: 53.12%
# Time elapsed: 40.22 min
# Epoch: 066/100 | Batch 0000/0032 | Loss: 1.6871
# Epoch: 066/100 | Train: 54.16% | Validation: 53.12%
# Time elapsed: 40.90 min
# Epoch: 067/100 | Batch 0000/0032 | Loss: 1.7701
# Epoch: 067/100 | Train: 54.63% | Validation: 53.12%
# Time elapsed: 41.59 min
# Epoch: 068/100 | Batch 0000/0032 | Loss: 1.7815
# Epoch: 068/100 | Train: 54.25% | Validation: 52.89%
# Time elapsed: 42.27 min
# Epoch: 069/100 | Batch 0000/0032 | Loss: 1.8443
# Epoch: 069/100 | Train: 53.99% | Validation: 53.12%
# Time elapsed: 42.95 min
# Epoch: 070/100 | Batch 0000/0032 | Loss: 1.9308
# Epoch: 070/100 | Train: 54.13% | Validation: 53.12%
# Time elapsed: 43.64 min
# Epoch: 071/100 | Batch 0000/0032 | Loss: 1.9705
# Epoch: 071/100 | Train: 54.15% | Validation: 53.12%
# Time elapsed: 44.34 min
# Epoch: 072/100 | Batch 0000/0032 | Loss: 1.7787
# Epoch: 072/100 | Train: 54.28% | Validation: 53.12%
# Time elapsed: 45.02 min
# Epoch: 073/100 | Batch 0000/0032 | Loss: 1.8534
# Epoch: 073/100 | Train: 54.14% | Validation: 53.12%
# Time elapsed: 45.61 min
# Epoch: 074/100 | Batch 0000/0032 | Loss: 1.9268
# Epoch: 074/100 | Train: 53.76% | Validation: 53.12%
# Time elapsed: 46.17 min
# Epoch: 075/100 | Batch 0000/0032 | Loss: 1.7616
# Epoch: 075/100 | Train: 54.00% | Validation: 53.12%
# Time elapsed: 46.73 min
# Epoch: 076/100 | Batch 0000/0032 | Loss: 1.7788
# Epoch: 076/100 | Train: 54.25% | Validation: 53.12%
# Time elapsed: 47.28 min
# Epoch: 077/100 | Batch 0000/0032 | Loss: 2.0111
# Epoch: 077/100 | Train: 54.54% | Validation: 53.12%
# Time elapsed: 47.85 min
# Epoch: 078/100 | Batch 0000/0032 | Loss: 1.8238
# Epoch: 078/100 | Train: 54.57% | Validation: 53.12%
# Time elapsed: 48.40 min
# Epoch: 079/100 | Batch 0000/0032 | Loss: 1.9454
# Epoch: 079/100 | Train: 53.69% | Validation: 53.12%
# Time elapsed: 48.96 min
# Epoch: 080/100 | Batch 0000/0032 | Loss: 1.8262
# Epoch: 080/100 | Train: 54.65% | Validation: 53.12%
# Time elapsed: 49.53 min
# Epoch: 081/100 | Batch 0000/0032 | Loss: 1.8918
# Epoch: 081/100 | Train: 54.39% | Validation: 53.12%
# Time elapsed: 50.10 min
# Epoch: 082/100 | Batch 0000/0032 | Loss: 1.8587
# Epoch: 082/100 | Train: 53.98% | Validation: 53.12%
# Time elapsed: 50.66 min
# Epoch: 083/100 | Batch 0000/0032 | Loss: 1.8383
# Epoch: 083/100 | Train: 53.88% | Validation: 53.12%
# Time elapsed: 51.21 min
# Epoch: 084/100 | Batch 0000/0032 | Loss: 1.9322
# Epoch: 084/100 | Train: 54.44% | Validation: 53.12%
# Time elapsed: 51.77 min
# Epoch: 085/100 | Batch 0000/0032 | Loss: 1.9381
# Epoch: 085/100 | Train: 55.40% | Validation: 53.12%
# Time elapsed: 52.33 min
# Epoch: 086/100 | Batch 0000/0032 | Loss: 2.0597
# Epoch: 086/100 | Train: 53.69% | Validation: 53.12%
# Time elapsed: 52.88 min
# Epoch: 087/100 | Batch 0000/0032 | Loss: 1.9837
# Epoch: 087/100 | Train: 54.37% | Validation: 53.12%
# Time elapsed: 53.44 min
# Epoch: 088/100 | Batch 0000/0032 | Loss: 1.9200
# Epoch: 088/100 | Train: 53.99% | Validation: 53.12%
# Time elapsed: 53.99 min
# Epoch: 089/100 | Batch 0000/0032 | Loss: 1.8508
# Epoch: 089/100 | Train: 53.91% | Validation: 53.12%
# Time elapsed: 54.55 min
# Epoch: 090/100 | Batch 0000/0032 | Loss: 1.7575
# Epoch: 090/100 | Train: 54.36% | Validation: 53.12%
# Time elapsed: 55.10 min
# Epoch: 091/100 | Batch 0000/0032 | Loss: 1.8749
# Epoch: 091/100 | Train: 54.55% | Validation: 53.12%
# Time elapsed: 55.66 min
# Epoch: 092/100 | Batch 0000/0032 | Loss: 1.9919
# Epoch: 092/100 | Train: 54.27% | Validation: 53.12%
# Time elapsed: 56.21 min
# Epoch: 093/100 | Batch 0000/0032 | Loss: 1.8663
# Epoch: 093/100 | Train: 54.44% | Validation: 53.12%
# Time elapsed: 56.77 min
# Epoch: 094/100 | Batch 0000/0032 | Loss: 2.1146
# Epoch: 094/100 | Train: 54.24% | Validation: 53.12%
# Time elapsed: 57.32 min
# Epoch: 095/100 | Batch 0000/0032 | Loss: 2.1262
# Epoch: 095/100 | Train: 54.66% | Validation: 53.12%
# Time elapsed: 57.88 min
# Epoch: 096/100 | Batch 0000/0032 | Loss: 1.8241
# Epoch: 096/100 | Train: 53.99% | Validation: 53.12%
# Time elapsed: 58.44 min
# Epoch: 097/100 | Batch 0000/0032 | Loss: 2.0389
# Epoch: 097/100 | Train: 54.35% | Validation: 53.12%
# Time elapsed: 59.00 min
# Epoch: 098/100 | Batch 0000/0032 | Loss: 1.9939
# Epoch: 098/100 | Train: 54.77% | Validation: 53.12%
# Time elapsed: 59.55 min
# Epoch: 099/100 | Batch 0000/0032 | Loss: 1.7868
# Epoch: 099/100 | Train: 54.22% | Validation: 53.12%
# Time elapsed: 60.11 min
# Epoch: 100/100 | Batch 0000/0032 | Loss: 1.8114
# Epoch: 100/100 | Train: 53.93% | Validation: 53.12%
# Time elapsed: 60.74 min
# Total Training Time: 60.74 min
# Test accuracy 61.12%

# %%
from torchsummary import summary
summary(model, input_size=(3, 128, 128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 31, 31]          23,296
#               Tanh-2           [-1, 64, 31, 31]               0
#          MaxPool2d-3           [-1, 64, 15, 15]               0
#             Conv2d-4          [-1, 192, 15, 15]         307,392
#               Tanh-5          [-1, 192, 15, 15]               0
#          MaxPool2d-6            [-1, 192, 7, 7]               0
#             Linear-7                  [-1, 512]       4,817,408
#               Tanh-8                  [-1, 512]               0
#             Linear-9                  [-1, 101]          51,813
# ================================================================
# Total params: 5,199,909
# Trainable params: 5,199,909
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 1.79
# Params size (MB): 19.84
# Estimated Total Size (MB): 21.81
# ----------------------------------------------------------------

# %%
##########################
### SAVE MODEL
##########################
model.to(torch.device('cpu'))
os.makedirs('./models/cnn1-v3', exist_ok=True)
torch.save(model.state_dict(), './models/cnn1-v3/cnn1-v3.pt')
torch.save(optimizer.state_dict(), './models/cnn1-v3/cnn1-v3-optimizer.pt')
torch.save(scheduler.state_dict(), './models/cnn1-v3/cnn1-v3-scheduler.pt')
